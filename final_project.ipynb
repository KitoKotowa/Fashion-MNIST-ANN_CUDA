# %% [markdown]
# <div style="text-align: center; background-color: #4682B4; padding: 40px; border-radius: 5px;">
#     <h1> Parallelizing and Optimizing Artificial Neural Networks for Fashion-MNIST using CUDA </h1>
# </div>

# %% [markdown]
# #### Group: 13
#
# | **#** | **Student ID** | **Name**             |
# |-------|----------------|----------------------|
# | 1     | 21127159       | Nguyễn Cao Sơn       |
# | 2     | 21127606       | Bùi Nguyên Hanh      |
# | 3     | 21127329       | Châu Tấn Kiệt        |

# %% [markdown]
# # <u> **Introduction**</u>
#
# The goal of this project is to implement and optimize an Artificial Neural Network (ANN) for the Fashion-MNIST dataset using CUDA for parallel computations. The project aims to demonstrate the efficiency of GPU-based computations through various optimization techniques and evaluate the performance improvements over baseline implementations.
#
# #### **Project Objectives**
# 1. **Implementation**: Develop a fully functional ANN with:
#    - One input layer (784 nodes for 28x28 grayscale images).
#    - Two hidden layers (128 nodes each, with ReLU activation).
#    - One output layer (10 nodes for classification, with Softmax activation).
# 2. **Optimization**: Apply GPU optimization techniques, such as:
#    - Basic convolution kernel.
#    - Shared memory and kernel fusion.
#    - CUDA streams to overlap computations and memory transfers.
# 3. **Performance Evaluation**: Measure and analyze runtime improvements and memory efficiency.
#
#
# #### **Dataset Overview**
# Fashion-MNIST is a widely used dataset for machine learning and deep learning. It serves as a direct replacement for the classic MNIST dataset but introduces more complex visual patterns to represent 10 fashion categories. The dataset consists of:
# - **Training Data**: 60,000 grayscale images, each labeled with one of 10 classes.
# - **Test Data**: 10,000 grayscale images.
# - **Image Details**:
#   - Size: 28x28 pixels.
#   - Format: Grayscale, normalized to values between 0 and 1.
#
# **Classes**:
#
# | **Category**    | **Category**     |
# |------------------|------------------|
# | T-shirt/top      | Sandal           |
# | Trouser          | Shirt            |
# | Pullover         | Sneaker          |
# | Dress            | Bag              |
# | Coat             | Ankle boot       |
#
#
# Fashion-MNIST is challenging compared to MNIST due to the higher similarity between classes (e.g., T-shirt and Shirt), making it an excellent benchmark for testing ANN performance.
#
# ---

# %% [markdown]
# # <u> **1. Application Description** </u>
#
# #### **What is your chosen application?**
# The chosen application is the implementation and optimization of an Artificial Neural Network (ANN) to classify images from the Fashion-MNIST dataset using CUDA for GPU acceleration. This project aims to demonstrate how parallel computing techniques can significantly enhance the efficiency of deep learning models.
#
# - **Input**:
#   Each input is a grayscale image of size $ 28 \times 28 $ pixels (flattened into a `784-dimensional vector`). The dataset includes `60,000 training images` and `10,000 test images`, representing `10 different classes` of fashion items.
#
# - **Output**:
#   The output is a probability distribution over the 10 fashion categories, such as T-shirt/top, trouser, or ankle boot. The model predicts the class with the highest probability.
#
# - **Use Cases**:
#   - Classification of fashion products in e-commerce platforms.
#   - Assisting inventory systems to automatically recognize and categorize apparel.
#   - Building real-time recommender systems for fashion items.
#
#
# #### **Does it need to speed up?**
# Yes, speeding up the application is critical due to the following reasons:
# 1. **Computational Intensity**:
#    The training of an ANN involves complex matrix operations (forward propagation, backpropagation) that scale with the size of the dataset and network layers. Running these operations sequentially on a CPU is time-consuming.
#
# 2. **Large Dataset**:
#    Fashion-MNIST consists of tens of thousands of high-dimensional data points, requiring efficient processing to complete training in a reasonable timeframe.
#
# 3. **Use of GPU Parallelism**:
#    CUDA enables the parallel execution of tasks such as matrix multiplications, activation functions, and gradient calculations, significantly reducing training time.
#
# This project highlights the use of **sequential implementation** as a baseline and **parallelized GPU-based optimization** to achieve improved performance. The outcomes will show how leveraging parallelism impacts real-world applications in AI and machine learning.

# %% [markdown]
# # <u> **2. Sequential Implementation**  </u>
#
# #### **Design**
# The sequential implementation involves executing the entire neural network training process step-by-step on the CPU, from input to output.
#
#
# **Step 1: Dataset Loading**
# - **Input**:
#   - Fashion-MNIST dataset files: `train-images-idx3-ubyte` and `train-labels-idx1-ubyte`.
# - **Process**:
#   1. Open the binary files containing the image data and labels.
#   2. Extract the metadata:
#      - Number of images.
#      - Image dimensions (28x28 pixels).
#   3. Normalize pixel values from $[0, 255]$ to $[0, 1]$ for better numerical stability during training.
#   4. Store images as flattened vectors of size $784$ and labels as integers.
# - **Output**:
#   - A list of normalized image vectors.
#   - A corresponding list of integer labels.
#
#
# **Step 2: Model Initialization**
# - **Input**:
#   - Neural network architecture details:
#     - Input layer: $784$ nodes.
#     - Two hidden layers: $128$ nodes each (with ReLU activation).
#     - Output layer: $10$ nodes (with Softmax activation).
# - **Process**:
#   1. Initialize weight matrices ($W1, W2, W3$) and bias vectors ($b1, b2, b3$) for each layer.
#   2. Use **Xavier initialization** to set weights to small random values:
#      $$
#      W \sim \mathcal{N}\left(0, \sqrt{\frac{2}{\text{in\_nodes} + \text{out\_nodes}}}\right)
#      $$
#   3. Set biases to zeros.
# - **Output**:
#   - Initialized weights and biases ready for training.
#
#
# **Step 3: Forward Propagation**
# - **Input**:
#   - A single normalized image vector (size $784$).
#   - Initialized weights and biases.
# - **Process**:
#   1. **Layer 1 (Input to Hidden Layer 1)**:
#      - Compute $Z1 = W1 \cdot X + b1$, where:
#        - $Z1$ is the pre-activation output.
#        - $X$ is the input vector.
#      - Apply ReLU activation:
#        $$
#        A1 = \text{ReLU}(Z1) = \max(0, Z1)
#        $$
#   2. **Layer 2 (Hidden Layer 1 to Hidden Layer 2)**:
#      - Compute $Z2 = W2 \cdot A1 + b2$.
#      - Apply ReLU activation:
#        $$
#        A2 = \text{ReLU}(Z2) = \max(0, Z2)
#        $$
#   3. **Output Layer (Hidden Layer 2 to Output)**:
#      - Compute $Z3 = W3 \cdot A2 + b3$.
#      - Apply Softmax activation:
#        $$
#        \text{Softmax}(Z3_i) = \frac{\exp(Z3_i)}{\sum_j \exp(Z3_j)}
#        $$
# - **Output**:
#   - The final probability distribution over the $10$ output classes.
#
#
# **Step 4: Loss Calculation**
# - **Input**:
#   - Model output probabilities from the Softmax function.
#   - True label (one-hot encoded vector).
# - **Process**:
#   - Compute the **Cross-Entropy Loss**:
#     $$
#     L = -\sum_{i=1}^{10} y_i \cdot \log(\hat{y}_i)
#     $$
#     Where:
#     - $y_i$ is the true label (one-hot encoded).
#     - $\hat{y}_i$ is the predicted probability for class $i$.
# - **Output**:
#   - Scalar loss value representing the model's error.
#
#
# **Step 5: Backward Propagation**
# - **Input**:
#   - Output probabilities, true label, and intermediate activations ($A1, A2$).
# - **Process**:
#   1. **Output Layer Gradients**:
#      - Compute:
#        $$
#        \delta_3 = \hat{y} - y
#        $$
#        $$
#        \frac{\partial L}{\partial W3} = \delta_3 \cdot A2^T
#        $$
#        $$
#        \frac{\partial L}{\partial b3} = \delta_3
#        $$
#   2. **Hidden Layer 2 Gradients**:
#      - Backpropagate the error:
#        $$
#        \delta_2 = (W3^T \cdot \delta_3) \circ \text{ReLU}'(Z2)
#        $$
#        $$
#        \frac{\partial L}{\partial W2} = \delta_2 \cdot A1^T
#        $$
#        $$
#        \frac{\partial L}{\partial b2} = \delta_2
#        $$
#   3. **Hidden Layer 1 Gradients**:
#      - Backpropagate further:
#        $$
#        \delta_1 = (W2^T \cdot \delta_2) \circ \text{ReLU}'(Z1)
#        $$
#        $$
#        \frac{\partial L}{\partial W1} = \delta_1 \cdot X^T
#        $$
#        $$
#        \frac{\partial L}{\partial b1} = \delta_1
#        $$
# - **Output**:
#   - Gradients for all weights and biases.
#
#
# **Step 6: Parameter Update**
# - **Input**:
#   - Gradients ($\frac{\partial L}{\partial W}, \frac{\partial L}{\partial b}$).
#   - Learning rate ($\eta$).
# - **Process**:
#   - Update weights and biases:
#     $$
#     W = W - \eta \cdot \frac{\partial L}{\partial W}
#     $$
#     $$
#     b = b - \eta \cdot \frac{\partial L}{\partial b}
#     $$
# - **Output**:
#   - Updated weights and biases.
#
#
# **Step 7: Training Loop**
# - **Process**:
#   1. Repeat steps 3-6 for all training samples in an epoch.
#   2. Track metrics such as:
#      - Average loss per epoch.
#      - Accuracy on training data.
#   3. Continue for a fixed number of epochs or until convergence.
# - **Output**:
#   - Final trained model parameters.
#
#
# #### **Evaluate**
#
# 1. **Experiment Setup**:
#    - Run on a CPU using the Eigen library for linear algebra.
#       - Try on PC and Colab
#    - Use the entire Fashion-MNIST dataset for training.
#       - `train-images-idx3-ubyte`
#       - `train-labels-idx1-ubyte`
#
# 2. **Execution**:
#    - Observe the training process over multiple epochs (about 10 epochs).
#
# 3. **Correctness**:
#    - Check that the loss decreases over time.
#    - Verify the model's predictions against ground truth labels to confirm accuracy.
#
# ![{FD6AE7AA-2EA0-4961-8516-DE6DCFE84B28}.png](attachment:{FD6AE7AA-2EA0-4961-8516-DE6DCFE84B28}.png)

# %% [markdown]
# # <u> Parallel Implementation </u>
#
# #### **Parallelized Steps**
#
# 1. **Forward Propagation**
#    a) **Matrix Multiplication Operations (`matrix_multiply_kernel`)**
#    **Reason**:
#    - Highly parallelizable operation.
#    - Computationally intensive with  $ O(M \times N \times K) $  complexity.
#    - Each output element can be computed independently.
#    - Perfect for GPU's SIMD (Single Instruction, Multiple Data) architecture.
#
#    b) **ReLU Activation (`relu_kernel`)**
#    **Reason**:
#    - Element-wise operation.
#    - Each neuron's activation can be computed independently.
#    - No dependencies between elements.
#    - Easily parallelizable across multiple threads.
#
#    c) **Softmax Computation (`softmax_kernel`)**
#    - Requires two passes: max finding and exponential normalization.
#    - While there are dependencies (e.g., needs the sum of all elements), it can still benefit from parallel reduction.
#    - Critical for classification output.
#
# 2. **Backward Propagation**
#    **Complete Backward Pass (`backward_propagation_kernel`)**
#    **Reason**:
#    - Gradient computations involve matrix operations.
#    - Weight updates can be done in parallel.
#    - Multiple independent calculations are performed for each layer.
#
# ---

# %% [markdown]
# # <u> **4. Parallel Implementation + Optimization** </u>

# %% [markdown]
# ## **1. Optimization 1: Backward Propagation Kernel**
#
# The key optimization in this phase focuses on improving the backward propagation kernel for better performance and efficiency.
#
#
#
# #### **What is Optimized**
# - **Weight and Bias Updates**: Improved efficiency in updating weights and biases during backpropagation.
# - **Memory Access Patterns**: Optimized for faster and more efficient memory operations.
# - **Thread Synchronization**: Minimized overhead from thread synchronization to boost performance.
#
#
#
# #### **Why This Part**
# - **Computational Intensity**: Backward propagation is one of the most computationally expensive processes in training.
# - **Race Conditions**: Involves numerous parallel weight updates, which can lead to race conditions without proper handling.
# - **Memory Conflicts**: High potential for memory conflicts and synchronization overhead, requiring optimization.
#
#
#
# #### **Optimization Details**
#
# a) **Atomic Operations**:
# - Utilizes CUDA atomic operations to prevent race conditions.
# - Ensures thread-safe updates to weights and biases.
# - Eliminates the need for multiple synchronization barriers.
#
# b) **Grid/Block Configuration**:
# - Employs more efficient thread block organization.
# - Uses a single unified grid dimension for all layers.
# - Achieves better load balancing across streaming multiprocessors (SMs).
#
# c) **Memory Access Pattern**:
# - Improves shared memory usage for faster data access.
# - Optimizes memory coalescing to reduce latency.
# - Minimizes bank conflicts for smoother memory operations.
#
# d) **Synchronization Optimization**:
# - Reduces the number of `__syncthreads()` calls.
# - Places synchronization barriers more efficiently.
# - Implements better thread cooperation patterns to minimize idle time.
#
#
# #### **Other Benefits**
#
# 1. **Forward Propagation**:
#    - The structure remains unchanged but benefits from:
#    - Improved grid/block configuration.
#    - Enhanced memory access patterns via better thread organization.
#
# 2. **Memory Management**:
#    - Implements a more efficient allocation and deallocation pattern.
#    - Reuses allocated memory to minimize overhead.
#    - Reduces memory transfer operations between host and device.
#
# ---

# %% [markdown]
# ## **Optimization 2: Utilizing CUDA Streams for Asynchronous Execution**
#
# #### **Analyze**
# CUDA streams are used to enable asynchronous execution of tasks, allowing overlapping of computation and data transfers. This approach improves overall GPU utilization by minimizing idle time and increasing throughput.
#
#
# #### **Key Idea**
# - CUDA streams allow the GPU to execute multiple tasks concurrently by using separate execution queues.
# - Asynchronous execution enables overlapping tasks such as computation and memory transfers, reducing latency and improving performance.
#
# **Examples of Overlapping Tasks**:
# 1. Forward propagation runs while data for the next batch is transferred to the GPU.
# 2. Backward propagation executes while the output of forward propagation is copied back to the host.
#
#
# #### **Key Improvements**
#
# 1. **Using `cudaMemcpyAsync` for Asynchronous Data Transfers**:
#    - Input and target data are transferred asynchronously using separate streams:
#      - `stream1` for input data.
#      - `stream2` for target labels.
#    - Reduces the latency caused by waiting for data transfers to complete before starting computations.
#
# 2. **Separate Streams for Kernels**:
#    - **Stream3**: Executes the `forward_propagation_kernel`.
#    - **Stream4**: Executes the `backward_propagation_kernel`.
#    - Allows forward propagation to process the current batch while backward propagation processes the previous batch, enabling pipeline execution.
#
# 3. **Asynchronous Data Copying Back**:
#    - The output of the forward propagation is transferred back to the host asynchronously via `stream1`, allowing backward propagation to continue without waiting for the transfer to finish.
#
#
# #### **Optimized Process**
# 1. **Memory Allocation**:
#    - Similar to the standard memory allocation, but uses pinned memory for efficient asynchronous transfers.
#
# 2. **Copying Input and Target Data**:
#    - Input data is copied to the GPU asynchronously using `stream1`.
#    - Target labels are copied using `stream2`.
#
# 3. **Forward Propagation**:
#    - The `forward_propagation_kernel` runs in `stream3`, processing the current batch of data.
#
# 4. **Backward Propagation**:
#    - The `backward_propagation_kernel` runs in `stream4`, updating weights and biases for the previous batch.
#
# 5. **Asynchronous Output Transfer**:
#    - The output of the forward propagation is copied back to the host asynchronously via `stream1` while the GPU continues with backward propagation.
#
#
# #### **Benefits of CUDA Streams**
# - **Reduced Latency**:
#   - Overlapping data transfers and computations minimizes idle time and reduces overall latency.
# - **Increased Throughput**:
#   - Parallel execution of tasks allows the GPU to handle more operations in the same timeframe.
# - **Better GPU Utilization**:
#   - Tasks across different streams make full use of available GPU resources, maximizing performance.

# %% [markdown]
# ### **5. Reflection**
#
# #### **Difficulties**
# - Managing data transfers between CPU and GPU while optimizing memory coalescing required significant effort.
# - Synchronizing team efforts and integrating GPU-optimized kernels with host code proved time-consuming.
# - Limited hardware availability slowed testing and debugging processes.
#
# #### **Learnings**
# - Gained a deeper understanding of CUDA programming, including kernel fusion, shared memory optimization, and asynchronous operations.
# - Learned the importance of profiling tools like `nvprof` to identify bottlenecks and improve performance.
# - Improved collaboration and problem-solving skills by combining expertise in CUDA, machine learning, and mathematical modeling.
#
# #### **What Would Be Improved or Added with More Time**
# 1. **Advanced Optimizations**:
#    - Utilize warp-level primitives and tensor cores for better performance.
#    - Implement mixed-precision training to improve speed and memory efficiency.
# 2. **Testing and Scalability**:
#    - Conduct broader testing across different hardware and datasets.
# 3. **Visualization and Documentation**:
#    - Add real-time training visualizations (loss and accuracy).
#    - Enhance documentation and provide a detailed user guide for future improvements.
#
# ---

# %% [markdown]
# ### **6. References**
# List materials and resources consulted during the project:
#   - [ANN Documentation](https://www.geeksforgeeks.org/building-artificial-neural-networks-ann-from-scratch).
#   - [CUDA Documentation](https://www.cs.utexas.edu/~rossbach/cs380p/papers/cuda-programming.pdf)
#   - [Eigen Library Documentation](https://eigen.tuxfamily.org/index.php?title=Main_Page#Download).
#   - [Fashion-MNIST Dataset Source](https://github.com/zalandoresearch/fashion-mnist).
#   - [Neural Network](http://neuralnetworksanddeeplearning.com/)
#   - [Layers in ANN](https://www.geeksforgeeks.org/layers-in-artificial-neural-networks-ann/)
# ---

# %% [markdown]
# # <u> Demonstration </u>

# %% [markdown]
# Environment setup - Eigen library installation

# %%
# !wget https://gitlab.com/libeigen/eigen/-/archive/3.4.0/eigen-3.4.0.tar.gz
# !tar -xvzf eigen-3.4.0.tar.gz
# Out:
# --2024-12-22 14:19:03--  https://gitlab.com/libeigen/eigen/-/archive/3.4.0/eigen-3.4.0.tar.gz
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘eigen-3.4.0.tar.gz’
#
# eigen-3.4.0.tar.gz      [ <=>                ]   2.58M  --.-KB/s    in 0.02s
#
# 2024-12-22 14:19:04 (139 MB/s) - ‘eigen-3.4.0.tar.gz’ saved [2705005]
#
# eigen-3.4.0/
# eigen-3.4.0/.gitignore
# eigen-3.4.0/.gitlab-ci.yml
# eigen-3.4.0/.gitlab/
# eigen-3.4.0/.gitlab/issue_templates/
# eigen-3.4.0/.gitlab/issue_templates/Bug Report.md
# eigen-3.4.0/.gitlab/issue_templates/Feature Request.md
# eigen-3.4.0/.gitlab/merge_request_templates/
# eigen-3.4.0/.gitlab/merge_request_templates/Merge Request Template.md
# eigen-3.4.0/.hgeol
# eigen-3.4.0/CMakeLists.txt
# eigen-3.4.0/COPYING.APACHE
# eigen-3.4.0/COPYING.BSD
# eigen-3.4.0/COPYING.GPL
# eigen-3.4.0/COPYING.LGPL
# eigen-3.4.0/COPYING.MINPACK
# eigen-3.4.0/COPYING.MPL2
# eigen-3.4.0/COPYING.README
# eigen-3.4.0/CTestConfig.cmake
# eigen-3.4.0/CTestCustom.cmake.in
# eigen-3.4.0/Eigen/
# eigen-3.4.0/Eigen/Cholesky
# eigen-3.4.0/Eigen/CholmodSupport
# eigen-3.4.0/Eigen/Core
# eigen-3.4.0/Eigen/Dense
# eigen-3.4.0/Eigen/Eigen
# eigen-3.4.0/Eigen/Eigenvalues
# eigen-3.4.0/Eigen/Geometry
# eigen-3.4.0/Eigen/Householder
# eigen-3.4.0/Eigen/IterativeLinearSolvers
# eigen-3.4.0/Eigen/Jacobi
# eigen-3.4.0/Eigen/KLUSupport
# eigen-3.4.0/Eigen/LU
# eigen-3.4.0/Eigen/MetisSupport
# eigen-3.4.0/Eigen/OrderingMethods
# eigen-3.4.0/Eigen/PaStiXSupport
# eigen-3.4.0/Eigen/PardisoSupport
# eigen-3.4.0/Eigen/QR
# eigen-3.4.0/Eigen/QtAlignedMalloc
# eigen-3.4.0/Eigen/SPQRSupport
# eigen-3.4.0/Eigen/SVD
# eigen-3.4.0/Eigen/Sparse
# eigen-3.4.0/Eigen/SparseCholesky
# eigen-3.4.0/Eigen/SparseCore
# eigen-3.4.0/Eigen/SparseLU
# eigen-3.4.0/Eigen/SparseQR
# eigen-3.4.0/Eigen/StdDeque
# eigen-3.4.0/Eigen/StdList
# eigen-3.4.0/Eigen/StdVector
# eigen-3.4.0/Eigen/SuperLUSupport
# eigen-3.4.0/Eigen/UmfPackSupport
# eigen-3.4.0/Eigen/src/
# eigen-3.4.0/Eigen/src/Cholesky/
# eigen-3.4.0/Eigen/src/Cholesky/LDLT.h
# eigen-3.4.0/Eigen/src/Cholesky/LLT.h
# eigen-3.4.0/Eigen/src/Cholesky/LLT_LAPACKE.h
# eigen-3.4.0/Eigen/src/CholmodSupport/
# eigen-3.4.0/Eigen/src/CholmodSupport/CholmodSupport.h
# eigen-3.4.0/Eigen/src/Core/
# eigen-3.4.0/Eigen/src/Core/ArithmeticSequence.h
# eigen-3.4.0/Eigen/src/Core/Array.h
# eigen-3.4.0/Eigen/src/Core/ArrayBase.h
# eigen-3.4.0/Eigen/src/Core/ArrayWrapper.h
# eigen-3.4.0/Eigen/src/Core/Assign.h
# eigen-3.4.0/Eigen/src/Core/AssignEvaluator.h
# eigen-3.4.0/Eigen/src/Core/Assign_MKL.h
# eigen-3.4.0/Eigen/src/Core/BandMatrix.h
# eigen-3.4.0/Eigen/src/Core/Block.h
# eigen-3.4.0/Eigen/src/Core/BooleanRedux.h
# eigen-3.4.0/Eigen/src/Core/CommaInitializer.h
# eigen-3.4.0/Eigen/src/Core/ConditionEstimator.h
# eigen-3.4.0/Eigen/src/Core/CoreEvaluators.h
# eigen-3.4.0/Eigen/src/Core/CoreIterators.h
# eigen-3.4.0/Eigen/src/Core/CwiseBinaryOp.h
# eigen-3.4.0/Eigen/src/Core/CwiseNullaryOp.h
# eigen-3.4.0/Eigen/src/Core/CwiseTernaryOp.h
# eigen-3.4.0/Eigen/src/Core/CwiseUnaryOp.h
# eigen-3.4.0/Eigen/src/Core/CwiseUnaryView.h
# eigen-3.4.0/Eigen/src/Core/DenseBase.h
# eigen-3.4.0/Eigen/src/Core/DenseCoeffsBase.h
# eigen-3.4.0/Eigen/src/Core/DenseStorage.h
# eigen-3.4.0/Eigen/src/Core/Diagonal.h
# eigen-3.4.0/Eigen/src/Core/DiagonalMatrix.h
# eigen-3.4.0/Eigen/src/Core/DiagonalProduct.h
# eigen-3.4.0/Eigen/src/Core/Dot.h
# eigen-3.4.0/Eigen/src/Core/EigenBase.h
# eigen-3.4.0/Eigen/src/Core/ForceAlignedAccess.h
# eigen-3.4.0/Eigen/src/Core/Fuzzy.h
# eigen-3.4.0/Eigen/src/Core/GeneralProduct.h
# eigen-3.4.0/Eigen/src/Core/GenericPacketMath.h
# eigen-3.4.0/Eigen/src/Core/GlobalFunctions.h
# eigen-3.4.0/Eigen/src/Core/IO.h
# eigen-3.4.0/Eigen/src/Core/IndexedView.h
# eigen-3.4.0/Eigen/src/Core/Inverse.h
# eigen-3.4.0/Eigen/src/Core/Map.h
# eigen-3.4.0/Eigen/src/Core/MapBase.h
# eigen-3.4.0/Eigen/src/Core/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/MathFunctionsImpl.h
# eigen-3.4.0/Eigen/src/Core/Matrix.h
# eigen-3.4.0/Eigen/src/Core/MatrixBase.h
# eigen-3.4.0/Eigen/src/Core/NestByValue.h
# eigen-3.4.0/Eigen/src/Core/NoAlias.h
# eigen-3.4.0/Eigen/src/Core/NumTraits.h
# eigen-3.4.0/Eigen/src/Core/PartialReduxEvaluator.h
# eigen-3.4.0/Eigen/src/Core/PermutationMatrix.h
# eigen-3.4.0/Eigen/src/Core/PlainObjectBase.h
# eigen-3.4.0/Eigen/src/Core/Product.h
# eigen-3.4.0/Eigen/src/Core/ProductEvaluators.h
# eigen-3.4.0/Eigen/src/Core/Random.h
# eigen-3.4.0/Eigen/src/Core/Redux.h
# eigen-3.4.0/Eigen/src/Core/Ref.h
# eigen-3.4.0/Eigen/src/Core/Replicate.h
# eigen-3.4.0/Eigen/src/Core/Reshaped.h
# eigen-3.4.0/Eigen/src/Core/ReturnByValue.h
# eigen-3.4.0/Eigen/src/Core/Reverse.h
# eigen-3.4.0/Eigen/src/Core/Select.h
# eigen-3.4.0/Eigen/src/Core/SelfAdjointView.h
# eigen-3.4.0/Eigen/src/Core/SelfCwiseBinaryOp.h
# eigen-3.4.0/Eigen/src/Core/Solve.h
# eigen-3.4.0/Eigen/src/Core/SolveTriangular.h
# eigen-3.4.0/Eigen/src/Core/SolverBase.h
# eigen-3.4.0/Eigen/src/Core/StableNorm.h
# eigen-3.4.0/Eigen/src/Core/StlIterators.h
# eigen-3.4.0/Eigen/src/Core/Stride.h
# eigen-3.4.0/Eigen/src/Core/Swap.h
# eigen-3.4.0/Eigen/src/Core/Transpose.h
# eigen-3.4.0/Eigen/src/Core/Transpositions.h
# eigen-3.4.0/Eigen/src/Core/TriangularMatrix.h
# eigen-3.4.0/Eigen/src/Core/VectorBlock.h
# eigen-3.4.0/Eigen/src/Core/VectorwiseOp.h
# eigen-3.4.0/Eigen/src/Core/Visitor.h
# eigen-3.4.0/Eigen/src/Core/arch/
# eigen-3.4.0/Eigen/src/Core/arch/AVX/
# eigen-3.4.0/Eigen/src/Core/arch/AVX/Complex.h
# eigen-3.4.0/Eigen/src/Core/arch/AVX/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/AVX/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/arch/AVX/TypeCasting.h
# eigen-3.4.0/Eigen/src/Core/arch/AVX512/
# eigen-3.4.0/Eigen/src/Core/arch/AVX512/Complex.h
# eigen-3.4.0/Eigen/src/Core/arch/AVX512/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/AVX512/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/arch/AVX512/TypeCasting.h
# eigen-3.4.0/Eigen/src/Core/arch/AltiVec/
# eigen-3.4.0/Eigen/src/Core/arch/AltiVec/Complex.h
# eigen-3.4.0/Eigen/src/Core/arch/AltiVec/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/AltiVec/MatrixProduct.h
# eigen-3.4.0/Eigen/src/Core/arch/AltiVec/MatrixProductCommon.h
# eigen-3.4.0/Eigen/src/Core/arch/AltiVec/MatrixProductMMA.h
# eigen-3.4.0/Eigen/src/Core/arch/AltiVec/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/arch/CUDA/
# eigen-3.4.0/Eigen/src/Core/arch/CUDA/Complex.h
# eigen-3.4.0/Eigen/src/Core/arch/Default/
# eigen-3.4.0/Eigen/src/Core/arch/Default/BFloat16.h
# eigen-3.4.0/Eigen/src/Core/arch/Default/ConjHelper.h
# eigen-3.4.0/Eigen/src/Core/arch/Default/GenericPacketMathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/Default/GenericPacketMathFunctionsFwd.h
# eigen-3.4.0/Eigen/src/Core/arch/Default/Half.h
# eigen-3.4.0/Eigen/src/Core/arch/Default/Settings.h
# eigen-3.4.0/Eigen/src/Core/arch/Default/TypeCasting.h
# eigen-3.4.0/Eigen/src/Core/arch/GPU/
# eigen-3.4.0/Eigen/src/Core/arch/GPU/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/GPU/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/arch/GPU/TypeCasting.h
# eigen-3.4.0/Eigen/src/Core/arch/HIP/
# eigen-3.4.0/Eigen/src/Core/arch/HIP/hcc/
# eigen-3.4.0/Eigen/src/Core/arch/HIP/hcc/math_constants.h
# eigen-3.4.0/Eigen/src/Core/arch/MSA/
# eigen-3.4.0/Eigen/src/Core/arch/MSA/Complex.h
# eigen-3.4.0/Eigen/src/Core/arch/MSA/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/MSA/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/arch/NEON/
# eigen-3.4.0/Eigen/src/Core/arch/NEON/Complex.h
# eigen-3.4.0/Eigen/src/Core/arch/NEON/GeneralBlockPanelKernel.h
# eigen-3.4.0/Eigen/src/Core/arch/NEON/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/NEON/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/arch/NEON/TypeCasting.h
# eigen-3.4.0/Eigen/src/Core/arch/SSE/
# eigen-3.4.0/Eigen/src/Core/arch/SSE/Complex.h
# eigen-3.4.0/Eigen/src/Core/arch/SSE/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/SSE/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/arch/SSE/TypeCasting.h
# eigen-3.4.0/Eigen/src/Core/arch/SVE/
# eigen-3.4.0/Eigen/src/Core/arch/SVE/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/SVE/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/arch/SVE/TypeCasting.h
# eigen-3.4.0/Eigen/src/Core/arch/SYCL/
# eigen-3.4.0/Eigen/src/Core/arch/SYCL/InteropHeaders.h
# eigen-3.4.0/Eigen/src/Core/arch/SYCL/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/SYCL/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/arch/SYCL/SyclMemoryModel.h
# eigen-3.4.0/Eigen/src/Core/arch/SYCL/TypeCasting.h
# eigen-3.4.0/Eigen/src/Core/arch/ZVector/
# eigen-3.4.0/Eigen/src/Core/arch/ZVector/Complex.h
# eigen-3.4.0/Eigen/src/Core/arch/ZVector/MathFunctions.h
# eigen-3.4.0/Eigen/src/Core/arch/ZVector/PacketMath.h
# eigen-3.4.0/Eigen/src/Core/functors/
# eigen-3.4.0/Eigen/src/Core/functors/AssignmentFunctors.h
# eigen-3.4.0/Eigen/src/Core/functors/BinaryFunctors.h
# eigen-3.4.0/Eigen/src/Core/functors/NullaryFunctors.h
# eigen-3.4.0/Eigen/src/Core/functors/StlFunctors.h
# eigen-3.4.0/Eigen/src/Core/functors/TernaryFunctors.h
# eigen-3.4.0/Eigen/src/Core/functors/UnaryFunctors.h
# eigen-3.4.0/Eigen/src/Core/products/
# eigen-3.4.0/Eigen/src/Core/products/GeneralBlockPanelKernel.h
# eigen-3.4.0/Eigen/src/Core/products/GeneralMatrixMatrix.h
# eigen-3.4.0/Eigen/src/Core/products/GeneralMatrixMatrixTriangular.h
# eigen-3.4.0/Eigen/src/Core/products/GeneralMatrixMatrixTriangular_BLAS.h
# eigen-3.4.0/Eigen/src/Core/products/GeneralMatrixMatrix_BLAS.h
# eigen-3.4.0/Eigen/src/Core/products/GeneralMatrixVector.h
# eigen-3.4.0/Eigen/src/Core/products/GeneralMatrixVector_BLAS.h
# eigen-3.4.0/Eigen/src/Core/products/Parallelizer.h
# eigen-3.4.0/Eigen/src/Core/products/SelfadjointMatrixMatrix.h
# eigen-3.4.0/Eigen/src/Core/products/SelfadjointMatrixMatrix_BLAS.h
# eigen-3.4.0/Eigen/src/Core/products/SelfadjointMatrixVector.h
# eigen-3.4.0/Eigen/src/Core/products/SelfadjointMatrixVector_BLAS.h
# eigen-3.4.0/Eigen/src/Core/products/SelfadjointProduct.h
# eigen-3.4.0/Eigen/src/Core/products/SelfadjointRank2Update.h
# eigen-3.4.0/Eigen/src/Core/products/TriangularMatrixMatrix.h
# eigen-3.4.0/Eigen/src/Core/products/TriangularMatrixMatrix_BLAS.h
# eigen-3.4.0/Eigen/src/Core/products/TriangularMatrixVector.h
# eigen-3.4.0/Eigen/src/Core/products/TriangularMatrixVector_BLAS.h
# eigen-3.4.0/Eigen/src/Core/products/TriangularSolverMatrix.h
# eigen-3.4.0/Eigen/src/Core/products/TriangularSolverMatrix_BLAS.h
# eigen-3.4.0/Eigen/src/Core/products/TriangularSolverVector.h
# eigen-3.4.0/Eigen/src/Core/util/
# eigen-3.4.0/Eigen/src/Core/util/BlasUtil.h
# eigen-3.4.0/Eigen/src/Core/util/ConfigureVectorization.h
# eigen-3.4.0/Eigen/src/Core/util/Constants.h
# eigen-3.4.0/Eigen/src/Core/util/DisableStupidWarnings.h
# eigen-3.4.0/Eigen/src/Core/util/ForwardDeclarations.h
# eigen-3.4.0/Eigen/src/Core/util/IndexedViewHelper.h
# eigen-3.4.0/Eigen/src/Core/util/IntegralConstant.h
# eigen-3.4.0/Eigen/src/Core/util/MKL_support.h
# eigen-3.4.0/Eigen/src/Core/util/Macros.h
# eigen-3.4.0/Eigen/src/Core/util/Memory.h
# eigen-3.4.0/Eigen/src/Core/util/Meta.h
# eigen-3.4.0/Eigen/src/Core/util/NonMPL2.h
# eigen-3.4.0/Eigen/src/Core/util/ReenableStupidWarnings.h
# eigen-3.4.0/Eigen/src/Core/util/ReshapedHelper.h
# eigen-3.4.0/Eigen/src/Core/util/StaticAssert.h
# eigen-3.4.0/Eigen/src/Core/util/SymbolicIndex.h
# eigen-3.4.0/Eigen/src/Core/util/XprHelper.h
# eigen-3.4.0/Eigen/src/Eigenvalues/
# eigen-3.4.0/Eigen/src/Eigenvalues/ComplexEigenSolver.h
# eigen-3.4.0/Eigen/src/Eigenvalues/ComplexSchur.h
# eigen-3.4.0/Eigen/src/Eigenvalues/ComplexSchur_LAPACKE.h
# eigen-3.4.0/Eigen/src/Eigenvalues/EigenSolver.h
# eigen-3.4.0/Eigen/src/Eigenvalues/GeneralizedEigenSolver.h
# eigen-3.4.0/Eigen/src/Eigenvalues/GeneralizedSelfAdjointEigenSolver.h
# eigen-3.4.0/Eigen/src/Eigenvalues/HessenbergDecomposition.h
# eigen-3.4.0/Eigen/src/Eigenvalues/MatrixBaseEigenvalues.h
# eigen-3.4.0/Eigen/src/Eigenvalues/RealQZ.h
# eigen-3.4.0/Eigen/src/Eigenvalues/RealSchur.h
# eigen-3.4.0/Eigen/src/Eigenvalues/RealSchur_LAPACKE.h
# eigen-3.4.0/Eigen/src/Eigenvalues/SelfAdjointEigenSolver.h
# eigen-3.4.0/Eigen/src/Eigenvalues/SelfAdjointEigenSolver_LAPACKE.h
# eigen-3.4.0/Eigen/src/Eigenvalues/Tridiagonalization.h
# eigen-3.4.0/Eigen/src/Geometry/
# eigen-3.4.0/Eigen/src/Geometry/AlignedBox.h
# eigen-3.4.0/Eigen/src/Geometry/AngleAxis.h
# eigen-3.4.0/Eigen/src/Geometry/EulerAngles.h
# eigen-3.4.0/Eigen/src/Geometry/Homogeneous.h
# eigen-3.4.0/Eigen/src/Geometry/Hyperplane.h
# eigen-3.4.0/Eigen/src/Geometry/OrthoMethods.h
# eigen-3.4.0/Eigen/src/Geometry/ParametrizedLine.h
# eigen-3.4.0/Eigen/src/Geometry/Quaternion.h
# eigen-3.4.0/Eigen/src/Geometry/Rotation2D.h
# eigen-3.4.0/Eigen/src/Geometry/RotationBase.h
# eigen-3.4.0/Eigen/src/Geometry/Scaling.h
# eigen-3.4.0/Eigen/src/Geometry/Transform.h
# eigen-3.4.0/Eigen/src/Geometry/Translation.h
# eigen-3.4.0/Eigen/src/Geometry/Umeyama.h
# eigen-3.4.0/Eigen/src/Geometry/arch/
# eigen-3.4.0/Eigen/src/Geometry/arch/Geometry_SIMD.h
# eigen-3.4.0/Eigen/src/Householder/
# eigen-3.4.0/Eigen/src/Householder/BlockHouseholder.h
# eigen-3.4.0/Eigen/src/Householder/Householder.h
# eigen-3.4.0/Eigen/src/Householder/HouseholderSequence.h
# eigen-3.4.0/Eigen/src/IterativeLinearSolvers/
# eigen-3.4.0/Eigen/src/IterativeLinearSolvers/BasicPreconditioners.h
# eigen-3.4.0/Eigen/src/IterativeLinearSolvers/BiCGSTAB.h
# eigen-3.4.0/Eigen/src/IterativeLinearSolvers/ConjugateGradient.h
# eigen-3.4.0/Eigen/src/IterativeLinearSolvers/IncompleteCholesky.h
# eigen-3.4.0/Eigen/src/IterativeLinearSolvers/IncompleteLUT.h
# eigen-3.4.0/Eigen/src/IterativeLinearSolvers/IterativeSolverBase.h
# eigen-3.4.0/Eigen/src/IterativeLinearSolvers/LeastSquareConjugateGradient.h
# eigen-3.4.0/Eigen/src/IterativeLinearSolvers/SolveWithGuess.h
# eigen-3.4.0/Eigen/src/Jacobi/
# eigen-3.4.0/Eigen/src/Jacobi/Jacobi.h
# eigen-3.4.0/Eigen/src/KLUSupport/
# eigen-3.4.0/Eigen/src/KLUSupport/KLUSupport.h
# eigen-3.4.0/Eigen/src/LU/
# eigen-3.4.0/Eigen/src/LU/Determinant.h
# eigen-3.4.0/Eigen/src/LU/FullPivLU.h
# eigen-3.4.0/Eigen/src/LU/InverseImpl.h
# eigen-3.4.0/Eigen/src/LU/PartialPivLU.h
# eigen-3.4.0/Eigen/src/LU/PartialPivLU_LAPACKE.h
# eigen-3.4.0/Eigen/src/LU/arch/
# eigen-3.4.0/Eigen/src/LU/arch/InverseSize4.h
# eigen-3.4.0/Eigen/src/MetisSupport/
# eigen-3.4.0/Eigen/src/MetisSupport/MetisSupport.h
# eigen-3.4.0/Eigen/src/OrderingMethods/
# eigen-3.4.0/Eigen/src/OrderingMethods/Amd.h
# eigen-3.4.0/Eigen/src/OrderingMethods/Eigen_Colamd.h
# eigen-3.4.0/Eigen/src/OrderingMethods/Ordering.h
# eigen-3.4.0/Eigen/src/PaStiXSupport/
# eigen-3.4.0/Eigen/src/PaStiXSupport/PaStiXSupport.h
# eigen-3.4.0/Eigen/src/PardisoSupport/
# eigen-3.4.0/Eigen/src/PardisoSupport/PardisoSupport.h
# eigen-3.4.0/Eigen/src/QR/
# eigen-3.4.0/Eigen/src/QR/ColPivHouseholderQR.h
# eigen-3.4.0/Eigen/src/QR/ColPivHouseholderQR_LAPACKE.h
# eigen-3.4.0/Eigen/src/QR/CompleteOrthogonalDecomposition.h
# eigen-3.4.0/Eigen/src/QR/FullPivHouseholderQR.h
# eigen-3.4.0/Eigen/src/QR/HouseholderQR.h
# eigen-3.4.0/Eigen/src/QR/HouseholderQR_LAPACKE.h
# eigen-3.4.0/Eigen/src/SPQRSupport/
# eigen-3.4.0/Eigen/src/SPQRSupport/SuiteSparseQRSupport.h
# eigen-3.4.0/Eigen/src/SVD/
# eigen-3.4.0/Eigen/src/SVD/BDCSVD.h
# eigen-3.4.0/Eigen/src/SVD/JacobiSVD.h
# eigen-3.4.0/Eigen/src/SVD/JacobiSVD_LAPACKE.h
# eigen-3.4.0/Eigen/src/SVD/SVDBase.h
# eigen-3.4.0/Eigen/src/SVD/UpperBidiagonalization.h
# eigen-3.4.0/Eigen/src/SparseCholesky/
# eigen-3.4.0/Eigen/src/SparseCholesky/SimplicialCholesky.h
# eigen-3.4.0/Eigen/src/SparseCholesky/SimplicialCholesky_impl.h
# eigen-3.4.0/Eigen/src/SparseCore/
# eigen-3.4.0/Eigen/src/SparseCore/AmbiVector.h
# eigen-3.4.0/Eigen/src/SparseCore/CompressedStorage.h
# eigen-3.4.0/Eigen/src/SparseCore/ConservativeSparseSparseProduct.h
# eigen-3.4.0/Eigen/src/SparseCore/MappedSparseMatrix.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseAssign.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseBlock.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseColEtree.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseCompressedBase.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseCwiseBinaryOp.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseCwiseUnaryOp.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseDenseProduct.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseDiagonalProduct.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseDot.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseFuzzy.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseMap.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseMatrix.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseMatrixBase.h
# eigen-3.4.0/Eigen/src/SparseCore/SparsePermutation.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseProduct.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseRedux.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseRef.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseSelfAdjointView.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseSolverBase.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseSparseProductWithPruning.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseTranspose.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseTriangularView.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseUtil.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseVector.h
# eigen-3.4.0/Eigen/src/SparseCore/SparseView.h
# eigen-3.4.0/Eigen/src/SparseCore/TriangularSolver.h
# eigen-3.4.0/Eigen/src/SparseLU/
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLUImpl.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_Memory.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_Structs.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_SupernodalMatrix.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_Utils.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_column_bmod.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_column_dfs.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_copy_to_ucol.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_gemm_kernel.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_heap_relax_snode.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_kernel_bmod.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_panel_bmod.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_panel_dfs.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_pivotL.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_pruneL.h
# eigen-3.4.0/Eigen/src/SparseLU/SparseLU_relax_snode.h
# eigen-3.4.0/Eigen/src/SparseQR/
# eigen-3.4.0/Eigen/src/SparseQR/SparseQR.h
# eigen-3.4.0/Eigen/src/StlSupport/
# eigen-3.4.0/Eigen/src/StlSupport/StdDeque.h
# eigen-3.4.0/Eigen/src/StlSupport/StdList.h
# eigen-3.4.0/Eigen/src/StlSupport/StdVector.h
# eigen-3.4.0/Eigen/src/StlSupport/details.h
# eigen-3.4.0/Eigen/src/SuperLUSupport/
# eigen-3.4.0/Eigen/src/SuperLUSupport/SuperLUSupport.h
# eigen-3.4.0/Eigen/src/UmfPackSupport/
# eigen-3.4.0/Eigen/src/UmfPackSupport/UmfPackSupport.h
# eigen-3.4.0/Eigen/src/misc/
# eigen-3.4.0/Eigen/src/misc/Image.h
# eigen-3.4.0/Eigen/src/misc/Kernel.h
# eigen-3.4.0/Eigen/src/misc/RealSvd2x2.h
# eigen-3.4.0/Eigen/src/misc/blas.h
# eigen-3.4.0/Eigen/src/misc/lapack.h
# eigen-3.4.0/Eigen/src/misc/lapacke.h
# eigen-3.4.0/Eigen/src/misc/lapacke_mangling.h
# eigen-3.4.0/Eigen/src/plugins/
# eigen-3.4.0/Eigen/src/plugins/ArrayCwiseBinaryOps.h
# eigen-3.4.0/Eigen/src/plugins/ArrayCwiseUnaryOps.h
# eigen-3.4.0/Eigen/src/plugins/BlockMethods.h
# eigen-3.4.0/Eigen/src/plugins/CommonCwiseBinaryOps.h
# eigen-3.4.0/Eigen/src/plugins/CommonCwiseUnaryOps.h
# eigen-3.4.0/Eigen/src/plugins/IndexedViewMethods.h
# eigen-3.4.0/Eigen/src/plugins/MatrixCwiseBinaryOps.h
# eigen-3.4.0/Eigen/src/plugins/MatrixCwiseUnaryOps.h
# eigen-3.4.0/Eigen/src/plugins/ReshapedMethods.h
# eigen-3.4.0/INSTALL
# eigen-3.4.0/README.md
# eigen-3.4.0/bench/
# eigen-3.4.0/bench/BenchSparseUtil.h
# eigen-3.4.0/bench/BenchTimer.h
# eigen-3.4.0/bench/BenchUtil.h
# eigen-3.4.0/bench/README.txt
# eigen-3.4.0/bench/analyze-blocking-sizes.cpp
# eigen-3.4.0/bench/basicbench.cxxlist
# eigen-3.4.0/bench/basicbenchmark.cpp
# eigen-3.4.0/bench/basicbenchmark.h
# eigen-3.4.0/bench/benchBlasGemm.cpp
# eigen-3.4.0/bench/benchCholesky.cpp
# eigen-3.4.0/bench/benchEigenSolver.cpp
# eigen-3.4.0/bench/benchFFT.cpp
# eigen-3.4.0/bench/benchGeometry.cpp
# eigen-3.4.0/bench/benchVecAdd.cpp
# eigen-3.4.0/bench/bench_gemm.cpp
# eigen-3.4.0/bench/bench_move_semantics.cpp
# eigen-3.4.0/bench/bench_multi_compilers.sh
# eigen-3.4.0/bench/bench_norm.cpp
# eigen-3.4.0/bench/bench_reverse.cpp
# eigen-3.4.0/bench/bench_sum.cpp
# eigen-3.4.0/bench/bench_unrolling
# eigen-3.4.0/bench/benchmark-blocking-sizes.cpp
# eigen-3.4.0/bench/benchmark.cpp
# eigen-3.4.0/bench/benchmarkSlice.cpp
# eigen-3.4.0/bench/benchmarkX.cpp
# eigen-3.4.0/bench/benchmarkXcwise.cpp
# eigen-3.4.0/bench/benchmark_suite
# eigen-3.4.0/bench/btl/
# eigen-3.4.0/bench/btl/CMakeLists.txt
# eigen-3.4.0/bench/btl/COPYING
# eigen-3.4.0/bench/btl/README
# eigen-3.4.0/bench/btl/actions/
# eigen-3.4.0/bench/btl/actions/action_aat_product.hh
# eigen-3.4.0/bench/btl/actions/action_ata_product.hh
# eigen-3.4.0/bench/btl/actions/action_atv_product.hh
# eigen-3.4.0/bench/btl/actions/action_axpby.hh
# eigen-3.4.0/bench/btl/actions/action_axpy.hh
# eigen-3.4.0/bench/btl/actions/action_cholesky.hh
# eigen-3.4.0/bench/btl/actions/action_ger.hh
# eigen-3.4.0/bench/btl/actions/action_hessenberg.hh
# eigen-3.4.0/bench/btl/actions/action_lu_decomp.hh
# eigen-3.4.0/bench/btl/actions/action_lu_solve.hh
# eigen-3.4.0/bench/btl/actions/action_matrix_matrix_product.hh
# eigen-3.4.0/bench/btl/actions/action_matrix_matrix_product_bis.hh
# eigen-3.4.0/bench/btl/actions/action_matrix_vector_product.hh
# eigen-3.4.0/bench/btl/actions/action_partial_lu.hh
# eigen-3.4.0/bench/btl/actions/action_rot.hh
# eigen-3.4.0/bench/btl/actions/action_symv.hh
# eigen-3.4.0/bench/btl/actions/action_syr2.hh
# eigen-3.4.0/bench/btl/actions/action_trisolve.hh
# eigen-3.4.0/bench/btl/actions/action_trisolve_matrix.hh
# eigen-3.4.0/bench/btl/actions/action_trmm.hh
# eigen-3.4.0/bench/btl/actions/basic_actions.hh
# eigen-3.4.0/bench/btl/cmake/
# eigen-3.4.0/bench/btl/cmake/FindACML.cmake
# eigen-3.4.0/bench/btl/cmake/FindATLAS.cmake
# eigen-3.4.0/bench/btl/cmake/FindBLAZE.cmake
# eigen-3.4.0/bench/btl/cmake/FindBlitz.cmake
# eigen-3.4.0/bench/btl/cmake/FindCBLAS.cmake
# eigen-3.4.0/bench/btl/cmake/FindGMM.cmake
# eigen-3.4.0/bench/btl/cmake/FindMKL.cmake
# eigen-3.4.0/bench/btl/cmake/FindMTL4.cmake
# eigen-3.4.0/bench/btl/cmake/FindOPENBLAS.cmake
# eigen-3.4.0/bench/btl/cmake/FindPackageHandleStandardArgs.cmake
# eigen-3.4.0/bench/btl/cmake/FindTvmet.cmake
# eigen-3.4.0/bench/btl/cmake/MacroOptionalAddSubdirectory.cmake
# eigen-3.4.0/bench/btl/data/
# eigen-3.4.0/bench/btl/data/CMakeLists.txt
# eigen-3.4.0/bench/btl/data/action_settings.txt
# eigen-3.4.0/bench/btl/data/gnuplot_common_settings.hh
# eigen-3.4.0/bench/btl/data/go_mean
# eigen-3.4.0/bench/btl/data/mean.cxx
# eigen-3.4.0/bench/btl/data/mk_gnuplot_script.sh
# eigen-3.4.0/bench/btl/data/mk_mean_script.sh
# eigen-3.4.0/bench/btl/data/mk_new_gnuplot.sh
# eigen-3.4.0/bench/btl/data/perlib_plot_settings.txt
# eigen-3.4.0/bench/btl/data/regularize.cxx
# eigen-3.4.0/bench/btl/data/smooth.cxx
# eigen-3.4.0/bench/btl/data/smooth_all.sh
# eigen-3.4.0/bench/btl/generic_bench/
# eigen-3.4.0/bench/btl/generic_bench/bench.hh
# eigen-3.4.0/bench/btl/generic_bench/bench_parameter.hh
# eigen-3.4.0/bench/btl/generic_bench/btl.hh
# eigen-3.4.0/bench/btl/generic_bench/init/
# eigen-3.4.0/bench/btl/generic_bench/init/init_function.hh
# eigen-3.4.0/bench/btl/generic_bench/init/init_matrix.hh
# eigen-3.4.0/bench/btl/generic_bench/init/init_vector.hh
# eigen-3.4.0/bench/btl/generic_bench/static/
# eigen-3.4.0/bench/btl/generic_bench/static/bench_static.hh
# eigen-3.4.0/bench/btl/generic_bench/static/intel_bench_fixed_size.hh
# eigen-3.4.0/bench/btl/generic_bench/static/static_size_generator.hh
# eigen-3.4.0/bench/btl/generic_bench/timers/
# eigen-3.4.0/bench/btl/generic_bench/timers/STL_perf_analyzer.hh
# eigen-3.4.0/bench/btl/generic_bench/timers/STL_timer.hh
# eigen-3.4.0/bench/btl/generic_bench/timers/mixed_perf_analyzer.hh
# eigen-3.4.0/bench/btl/generic_bench/timers/portable_perf_analyzer.hh
# eigen-3.4.0/bench/btl/generic_bench/timers/portable_perf_analyzer_old.hh
# eigen-3.4.0/bench/btl/generic_bench/timers/portable_timer.hh
# eigen-3.4.0/bench/btl/generic_bench/timers/x86_perf_analyzer.hh
# eigen-3.4.0/bench/btl/generic_bench/timers/x86_timer.hh
# eigen-3.4.0/bench/btl/generic_bench/utils/
# eigen-3.4.0/bench/btl/generic_bench/utils/size_lin_log.hh
# eigen-3.4.0/bench/btl/generic_bench/utils/size_log.hh
# eigen-3.4.0/bench/btl/generic_bench/utils/utilities.h
# eigen-3.4.0/bench/btl/generic_bench/utils/xy_file.hh
# eigen-3.4.0/bench/btl/libs/
# eigen-3.4.0/bench/btl/libs/BLAS/
# eigen-3.4.0/bench/btl/libs/BLAS/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/BLAS/blas.h
# eigen-3.4.0/bench/btl/libs/BLAS/blas_interface.hh
# eigen-3.4.0/bench/btl/libs/BLAS/blas_interface_impl.hh
# eigen-3.4.0/bench/btl/libs/BLAS/c_interface_base.h
# eigen-3.4.0/bench/btl/libs/BLAS/main.cpp
# eigen-3.4.0/bench/btl/libs/STL/
# eigen-3.4.0/bench/btl/libs/STL/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/STL/STL_interface.hh
# eigen-3.4.0/bench/btl/libs/STL/main.cpp
# eigen-3.4.0/bench/btl/libs/blaze/
# eigen-3.4.0/bench/btl/libs/blaze/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/blaze/blaze_interface.hh
# eigen-3.4.0/bench/btl/libs/blaze/main.cpp
# eigen-3.4.0/bench/btl/libs/blitz/
# eigen-3.4.0/bench/btl/libs/blitz/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/blitz/blitz_LU_solve_interface.hh
# eigen-3.4.0/bench/btl/libs/blitz/blitz_interface.hh
# eigen-3.4.0/bench/btl/libs/blitz/btl_blitz.cpp
# eigen-3.4.0/bench/btl/libs/blitz/btl_tiny_blitz.cpp
# eigen-3.4.0/bench/btl/libs/blitz/tiny_blitz_interface.hh
# eigen-3.4.0/bench/btl/libs/eigen2/
# eigen-3.4.0/bench/btl/libs/eigen2/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/eigen2/btl_tiny_eigen2.cpp
# eigen-3.4.0/bench/btl/libs/eigen2/eigen2_interface.hh
# eigen-3.4.0/bench/btl/libs/eigen2/main_adv.cpp
# eigen-3.4.0/bench/btl/libs/eigen2/main_linear.cpp
# eigen-3.4.0/bench/btl/libs/eigen2/main_matmat.cpp
# eigen-3.4.0/bench/btl/libs/eigen2/main_vecmat.cpp
# eigen-3.4.0/bench/btl/libs/eigen3/
# eigen-3.4.0/bench/btl/libs/eigen3/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/eigen3/btl_tiny_eigen3.cpp
# eigen-3.4.0/bench/btl/libs/eigen3/eigen3_interface.hh
# eigen-3.4.0/bench/btl/libs/eigen3/main_adv.cpp
# eigen-3.4.0/bench/btl/libs/eigen3/main_linear.cpp
# eigen-3.4.0/bench/btl/libs/eigen3/main_matmat.cpp
# eigen-3.4.0/bench/btl/libs/eigen3/main_vecmat.cpp
# eigen-3.4.0/bench/btl/libs/gmm/
# eigen-3.4.0/bench/btl/libs/gmm/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/gmm/gmm_LU_solve_interface.hh
# eigen-3.4.0/bench/btl/libs/gmm/gmm_interface.hh
# eigen-3.4.0/bench/btl/libs/gmm/main.cpp
# eigen-3.4.0/bench/btl/libs/mtl4/
# eigen-3.4.0/bench/btl/libs/mtl4/.kdbgrc.main
# eigen-3.4.0/bench/btl/libs/mtl4/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/mtl4/main.cpp
# eigen-3.4.0/bench/btl/libs/mtl4/mtl4_LU_solve_interface.hh
# eigen-3.4.0/bench/btl/libs/mtl4/mtl4_interface.hh
# eigen-3.4.0/bench/btl/libs/tensors/
# eigen-3.4.0/bench/btl/libs/tensors/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/tensors/main_linear.cpp
# eigen-3.4.0/bench/btl/libs/tensors/main_matmat.cpp
# eigen-3.4.0/bench/btl/libs/tensors/main_vecmat.cpp
# eigen-3.4.0/bench/btl/libs/tensors/tensor_interface.hh
# eigen-3.4.0/bench/btl/libs/tvmet/
# eigen-3.4.0/bench/btl/libs/tvmet/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/tvmet/main.cpp
# eigen-3.4.0/bench/btl/libs/tvmet/tvmet_interface.hh
# eigen-3.4.0/bench/btl/libs/ublas/
# eigen-3.4.0/bench/btl/libs/ublas/CMakeLists.txt
# eigen-3.4.0/bench/btl/libs/ublas/main.cpp
# eigen-3.4.0/bench/btl/libs/ublas/ublas_interface.hh
# eigen-3.4.0/bench/check_cache_queries.cpp
# eigen-3.4.0/bench/dense_solvers.cpp
# eigen-3.4.0/bench/eig33.cpp
# eigen-3.4.0/bench/geometry.cpp
# eigen-3.4.0/bench/perf_monitoring/
# eigen-3.4.0/bench/perf_monitoring/changesets.txt
# eigen-3.4.0/bench/perf_monitoring/gemm.cpp
# eigen-3.4.0/bench/perf_monitoring/gemm_common.h
# eigen-3.4.0/bench/perf_monitoring/gemm_settings.txt
# eigen-3.4.0/bench/perf_monitoring/gemm_square_settings.txt
# eigen-3.4.0/bench/perf_monitoring/gemv.cpp
# eigen-3.4.0/bench/perf_monitoring/gemv_common.h
# eigen-3.4.0/bench/perf_monitoring/gemv_settings.txt
# eigen-3.4.0/bench/perf_monitoring/gemv_square_settings.txt
# eigen-3.4.0/bench/perf_monitoring/gemvt.cpp
# eigen-3.4.0/bench/perf_monitoring/lazy_gemm.cpp
# eigen-3.4.0/bench/perf_monitoring/lazy_gemm_settings.txt
# eigen-3.4.0/bench/perf_monitoring/llt.cpp
# eigen-3.4.0/bench/perf_monitoring/make_plot.sh
# eigen-3.4.0/bench/perf_monitoring/resources/
# eigen-3.4.0/bench/perf_monitoring/resources/chart_footer.html
# eigen-3.4.0/bench/perf_monitoring/resources/chart_header.html
# eigen-3.4.0/bench/perf_monitoring/resources/footer.html
# eigen-3.4.0/bench/perf_monitoring/resources/header.html
# eigen-3.4.0/bench/perf_monitoring/resources/s1.js
# eigen-3.4.0/bench/perf_monitoring/resources/s2.js
# eigen-3.4.0/bench/perf_monitoring/run.sh
# eigen-3.4.0/bench/perf_monitoring/runall.sh
# eigen-3.4.0/bench/perf_monitoring/trmv_lo.cpp
# eigen-3.4.0/bench/perf_monitoring/trmv_lot.cpp
# eigen-3.4.0/bench/perf_monitoring/trmv_up.cpp
# eigen-3.4.0/bench/perf_monitoring/trmv_upt.cpp
# eigen-3.4.0/bench/product_threshold.cpp
# eigen-3.4.0/bench/quat_slerp.cpp
# eigen-3.4.0/bench/quatmul.cpp
# eigen-3.4.0/bench/sparse_cholesky.cpp
# eigen-3.4.0/bench/sparse_dense_product.cpp
# eigen-3.4.0/bench/sparse_lu.cpp
# eigen-3.4.0/bench/sparse_product.cpp
# eigen-3.4.0/bench/sparse_randomsetter.cpp
# eigen-3.4.0/bench/sparse_setter.cpp
# eigen-3.4.0/bench/sparse_transpose.cpp
# eigen-3.4.0/bench/sparse_trisolver.cpp
# eigen-3.4.0/bench/spbench/
# eigen-3.4.0/bench/spbench/CMakeLists.txt
# eigen-3.4.0/bench/spbench/sp_solver.cpp
# eigen-3.4.0/bench/spbench/spbench.dtd
# eigen-3.4.0/bench/spbench/spbenchsolver.cpp
# eigen-3.4.0/bench/spbench/spbenchsolver.h
# eigen-3.4.0/bench/spbench/spbenchstyle.h
# eigen-3.4.0/bench/spbench/test_sparseLU.cpp
# eigen-3.4.0/bench/spmv.cpp
# eigen-3.4.0/bench/tensors/
# eigen-3.4.0/bench/tensors/README
# eigen-3.4.0/bench/tensors/benchmark.h
# eigen-3.4.0/bench/tensors/benchmark_main.cc
# eigen-3.4.0/bench/tensors/contraction_benchmarks_cpu.cc
# eigen-3.4.0/bench/tensors/eigen_sycl_bench.sh
# eigen-3.4.0/bench/tensors/eigen_sycl_bench_contract.sh
# eigen-3.4.0/bench/tensors/tensor_benchmarks.h
# eigen-3.4.0/bench/tensors/tensor_benchmarks_cpu.cc
# eigen-3.4.0/bench/tensors/tensor_benchmarks_fp16_gpu.cu
# eigen-3.4.0/bench/tensors/tensor_benchmarks_gpu.cu
# eigen-3.4.0/bench/tensors/tensor_benchmarks_sycl.cc
# eigen-3.4.0/bench/tensors/tensor_contract_sycl_bench.cc
# eigen-3.4.0/bench/vdw_new.cpp
# eigen-3.4.0/blas/
# eigen-3.4.0/blas/BandTriangularSolver.h
# eigen-3.4.0/blas/CMakeLists.txt
# eigen-3.4.0/blas/GeneralRank1Update.h
# eigen-3.4.0/blas/PackedSelfadjointProduct.h
# eigen-3.4.0/blas/PackedTriangularMatrixVector.h
# eigen-3.4.0/blas/PackedTriangularSolverVector.h
# eigen-3.4.0/blas/README.txt
# eigen-3.4.0/blas/Rank2Update.h
# eigen-3.4.0/blas/common.h
# eigen-3.4.0/blas/complex_double.cpp
# eigen-3.4.0/blas/complex_single.cpp
# eigen-3.4.0/blas/double.cpp
# eigen-3.4.0/blas/f2c/
# eigen-3.4.0/blas/f2c/chbmv.c
# eigen-3.4.0/blas/f2c/chpmv.c
# eigen-3.4.0/blas/f2c/complexdots.c
# eigen-3.4.0/blas/f2c/ctbmv.c
# eigen-3.4.0/blas/f2c/d_cnjg.c
# eigen-3.4.0/blas/f2c/datatypes.h
# eigen-3.4.0/blas/f2c/drotm.c
# eigen-3.4.0/blas/f2c/drotmg.c
# eigen-3.4.0/blas/f2c/dsbmv.c
# eigen-3.4.0/blas/f2c/dspmv.c
# eigen-3.4.0/blas/f2c/dtbmv.c
# eigen-3.4.0/blas/f2c/lsame.c
# eigen-3.4.0/blas/f2c/r_cnjg.c
# eigen-3.4.0/blas/f2c/srotm.c
# eigen-3.4.0/blas/f2c/srotmg.c
# eigen-3.4.0/blas/f2c/ssbmv.c
# eigen-3.4.0/blas/f2c/sspmv.c
# eigen-3.4.0/blas/f2c/stbmv.c
# eigen-3.4.0/blas/f2c/zhbmv.c
# eigen-3.4.0/blas/f2c/zhpmv.c
# eigen-3.4.0/blas/f2c/ztbmv.c
# eigen-3.4.0/blas/fortran/
# eigen-3.4.0/blas/fortran/complexdots.f
# eigen-3.4.0/blas/level1_cplx_impl.h
# eigen-3.4.0/blas/level1_impl.h
# eigen-3.4.0/blas/level1_real_impl.h
# eigen-3.4.0/blas/level2_cplx_impl.h
# eigen-3.4.0/blas/level2_impl.h
# eigen-3.4.0/blas/level2_real_impl.h
# eigen-3.4.0/blas/level3_impl.h
# eigen-3.4.0/blas/single.cpp
# eigen-3.4.0/blas/testing/
# eigen-3.4.0/blas/testing/CMakeLists.txt
# eigen-3.4.0/blas/testing/cblat1.f
# eigen-3.4.0/blas/testing/cblat2.dat
# eigen-3.4.0/blas/testing/cblat2.f
# eigen-3.4.0/blas/testing/cblat3.dat
# eigen-3.4.0/blas/testing/cblat3.f
# eigen-3.4.0/blas/testing/dblat1.f
# eigen-3.4.0/blas/testing/dblat2.dat
# eigen-3.4.0/blas/testing/dblat2.f
# eigen-3.4.0/blas/testing/dblat3.dat
# eigen-3.4.0/blas/testing/dblat3.f
# eigen-3.4.0/blas/testing/runblastest.sh
# eigen-3.4.0/blas/testing/sblat1.f
# eigen-3.4.0/blas/testing/sblat2.dat
# eigen-3.4.0/blas/testing/sblat2.f
# eigen-3.4.0/blas/testing/sblat3.dat
# eigen-3.4.0/blas/testing/sblat3.f
# eigen-3.4.0/blas/testing/zblat1.f
# eigen-3.4.0/blas/testing/zblat2.dat
# eigen-3.4.0/blas/testing/zblat2.f
# eigen-3.4.0/blas/testing/zblat3.dat
# eigen-3.4.0/blas/testing/zblat3.f
# eigen-3.4.0/blas/xerbla.cpp
# eigen-3.4.0/ci/
# eigen-3.4.0/ci/CTest2JUnit.xsl
# eigen-3.4.0/ci/README.md
# eigen-3.4.0/ci/build.gitlab-ci.yml
# eigen-3.4.0/ci/smoketests.gitlab-ci.yml
# eigen-3.4.0/ci/test.gitlab-ci.yml
# eigen-3.4.0/cmake/
# eigen-3.4.0/cmake/ComputeCppCompilerChecks.cmake
# eigen-3.4.0/cmake/ComputeCppIRMap.cmake
# eigen-3.4.0/cmake/Eigen3Config.cmake.in
# eigen-3.4.0/cmake/Eigen3ConfigLegacy.cmake.in
# eigen-3.4.0/cmake/EigenConfigureTesting.cmake
# eigen-3.4.0/cmake/EigenDetermineOSVersion.cmake
# eigen-3.4.0/cmake/EigenDetermineVSServicePack.cmake
# eigen-3.4.0/cmake/EigenSmokeTestList.cmake
# eigen-3.4.0/cmake/EigenTesting.cmake
# eigen-3.4.0/cmake/EigenUninstall.cmake
# eigen-3.4.0/cmake/FindAdolc.cmake
# eigen-3.4.0/cmake/FindBLAS.cmake
# eigen-3.4.0/cmake/FindBLASEXT.cmake
# eigen-3.4.0/cmake/FindCHOLMOD.cmake
# eigen-3.4.0/cmake/FindComputeCpp.cmake
# eigen-3.4.0/cmake/FindEigen2.cmake
# eigen-3.4.0/cmake/FindEigen3.cmake
# eigen-3.4.0/cmake/FindFFTW.cmake
# eigen-3.4.0/cmake/FindGLEW.cmake
# eigen-3.4.0/cmake/FindGMP.cmake
# eigen-3.4.0/cmake/FindGSL.cmake
# eigen-3.4.0/cmake/FindGoogleHash.cmake
# eigen-3.4.0/cmake/FindHWLOC.cmake
# eigen-3.4.0/cmake/FindKLU.cmake
# eigen-3.4.0/cmake/FindLAPACK.cmake
# eigen-3.4.0/cmake/FindMPFR.cmake
# eigen-3.4.0/cmake/FindMPREAL.cmake
# eigen-3.4.0/cmake/FindMetis.cmake
# eigen-3.4.0/cmake/FindPASTIX.cmake
# eigen-3.4.0/cmake/FindPTSCOTCH.cmake
# eigen-3.4.0/cmake/FindSCOTCH.cmake
# eigen-3.4.0/cmake/FindSPQR.cmake
# eigen-3.4.0/cmake/FindStandardMathLibrary.cmake
# eigen-3.4.0/cmake/FindSuperLU.cmake
# eigen-3.4.0/cmake/FindTriSYCL.cmake
# eigen-3.4.0/cmake/FindUMFPACK.cmake
# eigen-3.4.0/cmake/RegexUtils.cmake
# eigen-3.4.0/cmake/UseEigen3.cmake
# eigen-3.4.0/debug/
# eigen-3.4.0/debug/gdb/
# eigen-3.4.0/debug/gdb/__init__.py
# eigen-3.4.0/debug/gdb/printers.py
# eigen-3.4.0/debug/msvc/
# eigen-3.4.0/debug/msvc/eigen.natvis
# eigen-3.4.0/debug/msvc/eigen_autoexp_part.dat
# eigen-3.4.0/demos/
# eigen-3.4.0/demos/CMakeLists.txt
# eigen-3.4.0/demos/mandelbrot/
# eigen-3.4.0/demos/mandelbrot/CMakeLists.txt
# eigen-3.4.0/demos/mandelbrot/README
# eigen-3.4.0/demos/mandelbrot/mandelbrot.cpp
# eigen-3.4.0/demos/mandelbrot/mandelbrot.h
# eigen-3.4.0/demos/mix_eigen_and_c/
# eigen-3.4.0/demos/mix_eigen_and_c/README
# eigen-3.4.0/demos/mix_eigen_and_c/binary_library.cpp
# eigen-3.4.0/demos/mix_eigen_and_c/binary_library.h
# eigen-3.4.0/demos/mix_eigen_and_c/example.c
# eigen-3.4.0/demos/opengl/
# eigen-3.4.0/demos/opengl/CMakeLists.txt
# eigen-3.4.0/demos/opengl/README
# eigen-3.4.0/demos/opengl/camera.cpp
# eigen-3.4.0/demos/opengl/camera.h
# eigen-3.4.0/demos/opengl/gpuhelper.cpp
# eigen-3.4.0/demos/opengl/gpuhelper.h
# eigen-3.4.0/demos/opengl/icosphere.cpp
# eigen-3.4.0/demos/opengl/icosphere.h
# eigen-3.4.0/demos/opengl/quaternion_demo.cpp
# eigen-3.4.0/demos/opengl/quaternion_demo.h
# eigen-3.4.0/demos/opengl/trackball.cpp
# eigen-3.4.0/demos/opengl/trackball.h
# eigen-3.4.0/doc/
# eigen-3.4.0/doc/AsciiQuickReference.txt
# eigen-3.4.0/doc/B01_Experimental.dox
# eigen-3.4.0/doc/CMakeLists.txt
# eigen-3.4.0/doc/ClassHierarchy.dox
# eigen-3.4.0/doc/CoeffwiseMathFunctionsTable.dox
# eigen-3.4.0/doc/CustomizingEigen_CustomScalar.dox
# eigen-3.4.0/doc/CustomizingEigen_InheritingMatrix.dox
# eigen-3.4.0/doc/CustomizingEigen_NullaryExpr.dox
# eigen-3.4.0/doc/CustomizingEigen_Plugins.dox
# eigen-3.4.0/doc/DenseDecompositionBenchmark.dox
# eigen-3.4.0/doc/Doxyfile.in
# eigen-3.4.0/doc/Eigen_Silly_Professor_64x64.png
# eigen-3.4.0/doc/FixedSizeVectorizable.dox
# eigen-3.4.0/doc/FunctionsTakingEigenTypes.dox
# eigen-3.4.0/doc/HiPerformance.dox
# eigen-3.4.0/doc/InplaceDecomposition.dox
# eigen-3.4.0/doc/InsideEigenExample.dox
# eigen-3.4.0/doc/LeastSquares.dox
# eigen-3.4.0/doc/Manual.dox
# eigen-3.4.0/doc/MatrixfreeSolverExample.dox
# eigen-3.4.0/doc/NewExpressionType.dox
# eigen-3.4.0/doc/Overview.dox
# eigen-3.4.0/doc/PassingByValue.dox
# eigen-3.4.0/doc/Pitfalls.dox
# eigen-3.4.0/doc/PreprocessorDirectives.dox
# eigen-3.4.0/doc/QuickReference.dox
# eigen-3.4.0/doc/QuickStartGuide.dox
# eigen-3.4.0/doc/SparseLinearSystems.dox
# eigen-3.4.0/doc/SparseQuickReference.dox
# eigen-3.4.0/doc/StlContainers.dox
# eigen-3.4.0/doc/StorageOrders.dox
# eigen-3.4.0/doc/StructHavingEigenMembers.dox
# eigen-3.4.0/doc/TemplateKeyword.dox
# eigen-3.4.0/doc/TopicAliasing.dox
# eigen-3.4.0/doc/TopicAssertions.dox
# eigen-3.4.0/doc/TopicCMakeGuide.dox
# eigen-3.4.0/doc/TopicEigenExpressionTemplates.dox
# eigen-3.4.0/doc/TopicLazyEvaluation.dox
# eigen-3.4.0/doc/TopicLinearAlgebraDecompositions.dox
# eigen-3.4.0/doc/TopicMultithreading.dox
# eigen-3.4.0/doc/TopicResizing.dox
# eigen-3.4.0/doc/TopicScalarTypes.dox
# eigen-3.4.0/doc/TopicVectorization.dox
# eigen-3.4.0/doc/TutorialAdvancedInitialization.dox
# eigen-3.4.0/doc/TutorialArrayClass.dox
# eigen-3.4.0/doc/TutorialBlockOperations.dox
# eigen-3.4.0/doc/TutorialGeometry.dox
# eigen-3.4.0/doc/TutorialLinearAlgebra.dox
# eigen-3.4.0/doc/TutorialMapClass.dox
# eigen-3.4.0/doc/TutorialMatrixArithmetic.dox
# eigen-3.4.0/doc/TutorialMatrixClass.dox
# eigen-3.4.0/doc/TutorialReductionsVisitorsBroadcasting.dox
# eigen-3.4.0/doc/TutorialReshape.dox
# eigen-3.4.0/doc/TutorialSTL.dox
# eigen-3.4.0/doc/TutorialSlicingIndexing.dox
# eigen-3.4.0/doc/TutorialSparse.dox
# eigen-3.4.0/doc/TutorialSparse_example_details.dox
# eigen-3.4.0/doc/UnalignedArrayAssert.dox
# eigen-3.4.0/doc/UsingBlasLapackBackends.dox
# eigen-3.4.0/doc/UsingIntelMKL.dox
# eigen-3.4.0/doc/UsingNVCC.dox
# eigen-3.4.0/doc/WrongStackAlignment.dox
# eigen-3.4.0/doc/eigen_navtree_hacks.js
# eigen-3.4.0/doc/eigendoxy.css
# eigen-3.4.0/doc/eigendoxy_footer.html.in
# eigen-3.4.0/doc/eigendoxy_header.html.in
# eigen-3.4.0/doc/eigendoxy_layout.xml.in
# eigen-3.4.0/doc/eigendoxy_tabs.css
# eigen-3.4.0/doc/examples/
# eigen-3.4.0/doc/examples/.krazy
# eigen-3.4.0/doc/examples/CMakeLists.txt
# eigen-3.4.0/doc/examples/CustomizingEigen_Inheritance.cpp
# eigen-3.4.0/doc/examples/Cwise_erf.cpp
# eigen-3.4.0/doc/examples/Cwise_erfc.cpp
# eigen-3.4.0/doc/examples/Cwise_lgamma.cpp
# eigen-3.4.0/doc/examples/DenseBase_middleCols_int.cpp
# eigen-3.4.0/doc/examples/DenseBase_middleRows_int.cpp
# eigen-3.4.0/doc/examples/DenseBase_template_int_middleCols.cpp
# eigen-3.4.0/doc/examples/DenseBase_template_int_middleRows.cpp
# eigen-3.4.0/doc/examples/QuickStart_example.cpp
# eigen-3.4.0/doc/examples/QuickStart_example2_dynamic.cpp
# eigen-3.4.0/doc/examples/QuickStart_example2_fixed.cpp
# eigen-3.4.0/doc/examples/TemplateKeyword_flexible.cpp
# eigen-3.4.0/doc/examples/TemplateKeyword_simple.cpp
# eigen-3.4.0/doc/examples/TutorialInplaceLU.cpp
# eigen-3.4.0/doc/examples/TutorialLinAlgComputeTwice.cpp
# eigen-3.4.0/doc/examples/TutorialLinAlgExComputeSolveError.cpp
# eigen-3.4.0/doc/examples/TutorialLinAlgExSolveColPivHouseholderQR.cpp
# eigen-3.4.0/doc/examples/TutorialLinAlgExSolveLDLT.cpp
# eigen-3.4.0/doc/examples/TutorialLinAlgInverseDeterminant.cpp
# eigen-3.4.0/doc/examples/TutorialLinAlgRankRevealing.cpp
# eigen-3.4.0/doc/examples/TutorialLinAlgSVDSolve.cpp
# eigen-3.4.0/doc/examples/TutorialLinAlgSelfAdjointEigenSolver.cpp
# eigen-3.4.0/doc/examples/TutorialLinAlgSetThreshold.cpp
# eigen-3.4.0/doc/examples/Tutorial_ArrayClass_accessors.cpp
# eigen-3.4.0/doc/examples/Tutorial_ArrayClass_addition.cpp
# eigen-3.4.0/doc/examples/Tutorial_ArrayClass_cwise_other.cpp
# eigen-3.4.0/doc/examples/Tutorial_ArrayClass_interop.cpp
# eigen-3.4.0/doc/examples/Tutorial_ArrayClass_interop_matrix.cpp
# eigen-3.4.0/doc/examples/Tutorial_ArrayClass_mult.cpp
# eigen-3.4.0/doc/examples/Tutorial_BlockOperations_block_assignment.cpp
# eigen-3.4.0/doc/examples/Tutorial_BlockOperations_colrow.cpp
# eigen-3.4.0/doc/examples/Tutorial_BlockOperations_corner.cpp
# eigen-3.4.0/doc/examples/Tutorial_BlockOperations_print_block.cpp
# eigen-3.4.0/doc/examples/Tutorial_BlockOperations_vector.cpp
# eigen-3.4.0/doc/examples/Tutorial_PartialLU_solve.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_broadcast_1nn.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_broadcast_simple.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_broadcast_simple_rowwise.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_colwise.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_maxnorm.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_reductions_bool.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_reductions_norm.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_reductions_operatornorm.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_rowwise.cpp
# eigen-3.4.0/doc/examples/Tutorial_ReductionsVisitorsBroadcasting_visitors.cpp
# eigen-3.4.0/doc/examples/Tutorial_simple_example_dynamic_size.cpp
# eigen-3.4.0/doc/examples/Tutorial_simple_example_fixed_size.cpp
# eigen-3.4.0/doc/examples/class_Block.cpp
# eigen-3.4.0/doc/examples/class_CwiseBinaryOp.cpp
# eigen-3.4.0/doc/examples/class_CwiseUnaryOp.cpp
# eigen-3.4.0/doc/examples/class_CwiseUnaryOp_ptrfun.cpp
# eigen-3.4.0/doc/examples/class_FixedBlock.cpp
# eigen-3.4.0/doc/examples/class_FixedReshaped.cpp
# eigen-3.4.0/doc/examples/class_FixedVectorBlock.cpp
# eigen-3.4.0/doc/examples/class_Reshaped.cpp
# eigen-3.4.0/doc/examples/class_VectorBlock.cpp
# eigen-3.4.0/doc/examples/function_taking_eigenbase.cpp
# eigen-3.4.0/doc/examples/function_taking_ref.cpp
# eigen-3.4.0/doc/examples/make_circulant.cpp
# eigen-3.4.0/doc/examples/make_circulant.cpp.entry
# eigen-3.4.0/doc/examples/make_circulant.cpp.evaluator
# eigen-3.4.0/doc/examples/make_circulant.cpp.expression
# eigen-3.4.0/doc/examples/make_circulant.cpp.main
# eigen-3.4.0/doc/examples/make_circulant.cpp.preamble
# eigen-3.4.0/doc/examples/make_circulant.cpp.traits
# eigen-3.4.0/doc/examples/make_circulant2.cpp
# eigen-3.4.0/doc/examples/matrixfree_cg.cpp
# eigen-3.4.0/doc/examples/nullary_indexing.cpp
# eigen-3.4.0/doc/examples/tut_arithmetic_add_sub.cpp
# eigen-3.4.0/doc/examples/tut_arithmetic_dot_cross.cpp
# eigen-3.4.0/doc/examples/tut_arithmetic_matrix_mul.cpp
# eigen-3.4.0/doc/examples/tut_arithmetic_redux_basic.cpp
# eigen-3.4.0/doc/examples/tut_arithmetic_scalar_mul_div.cpp
# eigen-3.4.0/doc/examples/tut_matrix_coefficient_accessors.cpp
# eigen-3.4.0/doc/examples/tut_matrix_resize.cpp
# eigen-3.4.0/doc/examples/tut_matrix_resize_fixed_size.cpp
# eigen-3.4.0/doc/ftv2node.png
# eigen-3.4.0/doc/ftv2pnode.png
# eigen-3.4.0/doc/snippets/
# eigen-3.4.0/doc/snippets/.krazy
# eigen-3.4.0/doc/snippets/AngleAxis_mimic_euler.cpp
# eigen-3.4.0/doc/snippets/Array_initializer_list_23_cxx11.cpp
# eigen-3.4.0/doc/snippets/Array_initializer_list_vector_cxx11.cpp
# eigen-3.4.0/doc/snippets/Array_variadic_ctor_cxx11.cpp
# eigen-3.4.0/doc/snippets/BiCGSTAB_simple.cpp
# eigen-3.4.0/doc/snippets/BiCGSTAB_step_by_step.cpp
# eigen-3.4.0/doc/snippets/CMakeLists.txt
# eigen-3.4.0/doc/snippets/ColPivHouseholderQR_solve.cpp
# eigen-3.4.0/doc/snippets/ComplexEigenSolver_compute.cpp
# eigen-3.4.0/doc/snippets/ComplexEigenSolver_eigenvalues.cpp
# eigen-3.4.0/doc/snippets/ComplexEigenSolver_eigenvectors.cpp
# eigen-3.4.0/doc/snippets/ComplexSchur_compute.cpp
# eigen-3.4.0/doc/snippets/ComplexSchur_matrixT.cpp
# eigen-3.4.0/doc/snippets/ComplexSchur_matrixU.cpp
# eigen-3.4.0/doc/snippets/Cwise_abs.cpp
# eigen-3.4.0/doc/snippets/Cwise_abs2.cpp
# eigen-3.4.0/doc/snippets/Cwise_acos.cpp
# eigen-3.4.0/doc/snippets/Cwise_arg.cpp
# eigen-3.4.0/doc/snippets/Cwise_array_power_array.cpp
# eigen-3.4.0/doc/snippets/Cwise_asin.cpp
# eigen-3.4.0/doc/snippets/Cwise_atan.cpp
# eigen-3.4.0/doc/snippets/Cwise_boolean_and.cpp
# eigen-3.4.0/doc/snippets/Cwise_boolean_not.cpp
# eigen-3.4.0/doc/snippets/Cwise_boolean_or.cpp
# eigen-3.4.0/doc/snippets/Cwise_boolean_xor.cpp
# eigen-3.4.0/doc/snippets/Cwise_ceil.cpp
# eigen-3.4.0/doc/snippets/Cwise_cos.cpp
# eigen-3.4.0/doc/snippets/Cwise_cosh.cpp
# eigen-3.4.0/doc/snippets/Cwise_cube.cpp
# eigen-3.4.0/doc/snippets/Cwise_equal_equal.cpp
# eigen-3.4.0/doc/snippets/Cwise_exp.cpp
# eigen-3.4.0/doc/snippets/Cwise_floor.cpp
# eigen-3.4.0/doc/snippets/Cwise_greater.cpp
# eigen-3.4.0/doc/snippets/Cwise_greater_equal.cpp
# eigen-3.4.0/doc/snippets/Cwise_inverse.cpp
# eigen-3.4.0/doc/snippets/Cwise_isFinite.cpp
# eigen-3.4.0/doc/snippets/Cwise_isInf.cpp
# eigen-3.4.0/doc/snippets/Cwise_isNaN.cpp
# eigen-3.4.0/doc/snippets/Cwise_less.cpp
# eigen-3.4.0/doc/snippets/Cwise_less_equal.cpp
# eigen-3.4.0/doc/snippets/Cwise_log.cpp
# eigen-3.4.0/doc/snippets/Cwise_log10.cpp
# eigen-3.4.0/doc/snippets/Cwise_max.cpp
# eigen-3.4.0/doc/snippets/Cwise_min.cpp
# eigen-3.4.0/doc/snippets/Cwise_minus.cpp
# eigen-3.4.0/doc/snippets/Cwise_minus_equal.cpp
# eigen-3.4.0/doc/snippets/Cwise_not_equal.cpp
# eigen-3.4.0/doc/snippets/Cwise_plus.cpp
# eigen-3.4.0/doc/snippets/Cwise_plus_equal.cpp
# eigen-3.4.0/doc/snippets/Cwise_pow.cpp
# eigen-3.4.0/doc/snippets/Cwise_product.cpp
# eigen-3.4.0/doc/snippets/Cwise_quotient.cpp
# eigen-3.4.0/doc/snippets/Cwise_rint.cpp
# eigen-3.4.0/doc/snippets/Cwise_round.cpp
# eigen-3.4.0/doc/snippets/Cwise_scalar_power_array.cpp
# eigen-3.4.0/doc/snippets/Cwise_sign.cpp
# eigen-3.4.0/doc/snippets/Cwise_sin.cpp
# eigen-3.4.0/doc/snippets/Cwise_sinh.cpp
# eigen-3.4.0/doc/snippets/Cwise_slash_equal.cpp
# eigen-3.4.0/doc/snippets/Cwise_sqrt.cpp
# eigen-3.4.0/doc/snippets/Cwise_square.cpp
# eigen-3.4.0/doc/snippets/Cwise_tan.cpp
# eigen-3.4.0/doc/snippets/Cwise_tanh.cpp
# eigen-3.4.0/doc/snippets/Cwise_times_equal.cpp
# eigen-3.4.0/doc/snippets/DenseBase_LinSpaced.cpp
# eigen-3.4.0/doc/snippets/DenseBase_LinSpacedInt.cpp
# eigen-3.4.0/doc/snippets/DenseBase_LinSpaced_seq_deprecated.cpp
# eigen-3.4.0/doc/snippets/DenseBase_setLinSpaced.cpp
# eigen-3.4.0/doc/snippets/DirectionWise_hnormalized.cpp
# eigen-3.4.0/doc/snippets/DirectionWise_replicate.cpp
# eigen-3.4.0/doc/snippets/DirectionWise_replicate_int.cpp
# eigen-3.4.0/doc/snippets/EigenSolver_EigenSolver_MatrixType.cpp
# eigen-3.4.0/doc/snippets/EigenSolver_compute.cpp
# eigen-3.4.0/doc/snippets/EigenSolver_eigenvalues.cpp
# eigen-3.4.0/doc/snippets/EigenSolver_eigenvectors.cpp
# eigen-3.4.0/doc/snippets/EigenSolver_pseudoEigenvectors.cpp
# eigen-3.4.0/doc/snippets/FullPivHouseholderQR_solve.cpp
# eigen-3.4.0/doc/snippets/FullPivLU_image.cpp
# eigen-3.4.0/doc/snippets/FullPivLU_kernel.cpp
# eigen-3.4.0/doc/snippets/FullPivLU_solve.cpp
# eigen-3.4.0/doc/snippets/GeneralizedEigenSolver.cpp
# eigen-3.4.0/doc/snippets/HessenbergDecomposition_compute.cpp
# eigen-3.4.0/doc/snippets/HessenbergDecomposition_matrixH.cpp
# eigen-3.4.0/doc/snippets/HessenbergDecomposition_packedMatrix.cpp
# eigen-3.4.0/doc/snippets/HouseholderQR_householderQ.cpp
# eigen-3.4.0/doc/snippets/HouseholderQR_solve.cpp
# eigen-3.4.0/doc/snippets/HouseholderSequence_HouseholderSequence.cpp
# eigen-3.4.0/doc/snippets/IOFormat.cpp
# eigen-3.4.0/doc/snippets/JacobiSVD_basic.cpp
# eigen-3.4.0/doc/snippets/Jacobi_makeGivens.cpp
# eigen-3.4.0/doc/snippets/Jacobi_makeJacobi.cpp
# eigen-3.4.0/doc/snippets/LLT_example.cpp
# eigen-3.4.0/doc/snippets/LLT_solve.cpp
# eigen-3.4.0/doc/snippets/LeastSquaresNormalEquations.cpp
# eigen-3.4.0/doc/snippets/LeastSquaresQR.cpp
# eigen-3.4.0/doc/snippets/Map_general_stride.cpp
# eigen-3.4.0/doc/snippets/Map_inner_stride.cpp
# eigen-3.4.0/doc/snippets/Map_outer_stride.cpp
# eigen-3.4.0/doc/snippets/Map_placement_new.cpp
# eigen-3.4.0/doc/snippets/Map_simple.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_adjoint.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_all.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_applyOnTheLeft.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_applyOnTheRight.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_array.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_array_const.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_asDiagonal.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_block_int_int.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_block_int_int_int_int.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_bottomLeftCorner_int_int.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_bottomRightCorner_int_int.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_bottomRows_int.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_cast.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_col.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_colwise.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_colwise_iterator_cxx11.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_computeInverseAndDetWithCheck.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_computeInverseWithCheck.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_cwiseAbs.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_cwiseAbs2.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_cwiseArg.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_cwiseEqual.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_cwiseInverse.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_cwiseMax.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_cwiseMin.cpp
# eigen-3.4.0/doc/snippets/MatrixBase_cwiseNotEqual.cpp
# ...
# eigen-3.4.0/unsupported/Eigen/EulerAngles
# eigen-3.4.0/unsupported/Eigen/FFT
# eigen-3.4.0/unsupported/Eigen/IterativeSolvers
# eigen-3.4.0/unsupported/Eigen/KroneckerProduct
# eigen-3.4.0/unsupported/Eigen/LevenbergMarquardt
# eigen-3.4.0/unsupported/Eigen/MPRealSupport
# eigen-3.4.0/unsupported/Eigen/MatrixFunctions
# eigen-3.4.0/unsupported/Eigen/MoreVectorization
# eigen-3.4.0/unsupported/Eigen/NonLinearOptimization
# eigen-3.4.0/unsupported/Eigen/NumericalDiff
# eigen-3.4.0/unsupported/Eigen/OpenGLSupport
# eigen-3.4.0/unsupported/Eigen/Polynomials
# eigen-3.4.0/unsupported/Eigen/Skyline
# eigen-3.4.0/unsupported/Eigen/SparseExtra
# eigen-3.4.0/unsupported/Eigen/SpecialFunctions
# eigen-3.4.0/unsupported/Eigen/Splines
# eigen-3.4.0/unsupported/Eigen/src/
# eigen-3.4.0/unsupported/Eigen/src/AutoDiff/
# eigen-3.4.0/unsupported/Eigen/src/AutoDiff/AutoDiffJacobian.h
# eigen-3.4.0/unsupported/Eigen/src/AutoDiff/AutoDiffScalar.h
# eigen-3.4.0/unsupported/Eigen/src/AutoDiff/AutoDiffVector.h
# eigen-3.4.0/unsupported/Eigen/src/BVH/
# eigen-3.4.0/unsupported/Eigen/src/BVH/BVAlgorithms.h
# eigen-3.4.0/unsupported/Eigen/src/BVH/KdBVH.h
# eigen-3.4.0/unsupported/Eigen/src/Eigenvalues/
# eigen-3.4.0/unsupported/Eigen/src/Eigenvalues/ArpackSelfAdjointEigenSolver.h
# eigen-3.4.0/unsupported/Eigen/src/EulerAngles/
# eigen-3.4.0/unsupported/Eigen/src/EulerAngles/CMakeLists.txt
# eigen-3.4.0/unsupported/Eigen/src/EulerAngles/EulerAngles.h
# eigen-3.4.0/unsupported/Eigen/src/EulerAngles/EulerSystem.h
# eigen-3.4.0/unsupported/Eigen/src/FFT/
# eigen-3.4.0/unsupported/Eigen/src/FFT/ei_fftw_impl.h
# eigen-3.4.0/unsupported/Eigen/src/FFT/ei_kissfft_impl.h
# eigen-3.4.0/unsupported/Eigen/src/IterativeSolvers/
# eigen-3.4.0/unsupported/Eigen/src/IterativeSolvers/ConstrainedConjGrad.h
# eigen-3.4.0/unsupported/Eigen/src/IterativeSolvers/DGMRES.h
# eigen-3.4.0/unsupported/Eigen/src/IterativeSolvers/GMRES.h
# eigen-3.4.0/unsupported/Eigen/src/IterativeSolvers/IDRS.h
# eigen-3.4.0/unsupported/Eigen/src/IterativeSolvers/IncompleteLU.h
# eigen-3.4.0/unsupported/Eigen/src/IterativeSolvers/IterationController.h
# eigen-3.4.0/unsupported/Eigen/src/IterativeSolvers/MINRES.h
# eigen-3.4.0/unsupported/Eigen/src/IterativeSolvers/Scaling.h
# eigen-3.4.0/unsupported/Eigen/src/KroneckerProduct/
# eigen-3.4.0/unsupported/Eigen/src/KroneckerProduct/KroneckerTensorProduct.h
# eigen-3.4.0/unsupported/Eigen/src/LevenbergMarquardt/
# eigen-3.4.0/unsupported/Eigen/src/LevenbergMarquardt/CopyrightMINPACK.txt
# eigen-3.4.0/unsupported/Eigen/src/LevenbergMarquardt/LMcovar.h
# eigen-3.4.0/unsupported/Eigen/src/LevenbergMarquardt/LMonestep.h
# eigen-3.4.0/unsupported/Eigen/src/LevenbergMarquardt/LMpar.h
# eigen-3.4.0/unsupported/Eigen/src/LevenbergMarquardt/LMqrsolv.h
# eigen-3.4.0/unsupported/Eigen/src/LevenbergMarquardt/LevenbergMarquardt.h
# eigen-3.4.0/unsupported/Eigen/src/MatrixFunctions/
# eigen-3.4.0/unsupported/Eigen/src/MatrixFunctions/MatrixExponential.h
# eigen-3.4.0/unsupported/Eigen/src/MatrixFunctions/MatrixFunction.h
# eigen-3.4.0/unsupported/Eigen/src/MatrixFunctions/MatrixLogarithm.h
# eigen-3.4.0/unsupported/Eigen/src/MatrixFunctions/MatrixPower.h
# eigen-3.4.0/unsupported/Eigen/src/MatrixFunctions/MatrixSquareRoot.h
# eigen-3.4.0/unsupported/Eigen/src/MatrixFunctions/StemFunction.h
# eigen-3.4.0/unsupported/Eigen/src/MoreVectorization/
# eigen-3.4.0/unsupported/Eigen/src/MoreVectorization/MathFunctions.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/HybridNonLinearSolver.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/LevenbergMarquardt.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/chkder.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/covar.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/dogleg.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/fdjac1.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/lmpar.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/qrsolv.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/r1mpyq.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/r1updt.h
# eigen-3.4.0/unsupported/Eigen/src/NonLinearOptimization/rwupdt.h
# eigen-3.4.0/unsupported/Eigen/src/NumericalDiff/
# eigen-3.4.0/unsupported/Eigen/src/NumericalDiff/NumericalDiff.h
# eigen-3.4.0/unsupported/Eigen/src/Polynomials/
# eigen-3.4.0/unsupported/Eigen/src/Polynomials/Companion.h
# eigen-3.4.0/unsupported/Eigen/src/Polynomials/PolynomialSolver.h
# eigen-3.4.0/unsupported/Eigen/src/Polynomials/PolynomialUtils.h
# eigen-3.4.0/unsupported/Eigen/src/Skyline/
# eigen-3.4.0/unsupported/Eigen/src/Skyline/SkylineInplaceLU.h
# eigen-3.4.0/unsupported/Eigen/src/Skyline/SkylineMatrix.h
# eigen-3.4.0/unsupported/Eigen/src/Skyline/SkylineMatrixBase.h
# eigen-3.4.0/unsupported/Eigen/src/Skyline/SkylineProduct.h
# eigen-3.4.0/unsupported/Eigen/src/Skyline/SkylineStorage.h
# eigen-3.4.0/unsupported/Eigen/src/Skyline/SkylineUtil.h
# eigen-3.4.0/unsupported/Eigen/src/SparseExtra/
# eigen-3.4.0/unsupported/Eigen/src/SparseExtra/BlockOfDynamicSparseMatrix.h
# eigen-3.4.0/unsupported/Eigen/src/SparseExtra/BlockSparseMatrix.h
# eigen-3.4.0/unsupported/Eigen/src/SparseExtra/DynamicSparseMatrix.h
# eigen-3.4.0/unsupported/Eigen/src/SparseExtra/MarketIO.h
# eigen-3.4.0/unsupported/Eigen/src/SparseExtra/MatrixMarketIterator.h
# eigen-3.4.0/unsupported/Eigen/src/SparseExtra/RandomSetter.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/BesselFunctionsArrayAPI.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/BesselFunctionsBFloat16.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/BesselFunctionsFunctors.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/BesselFunctionsHalf.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/BesselFunctionsImpl.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/BesselFunctionsPacketMath.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/HipVectorCompatibility.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/SpecialFunctionsArrayAPI.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/SpecialFunctionsBFloat16.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/SpecialFunctionsFunctors.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/SpecialFunctionsHalf.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/SpecialFunctionsImpl.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/SpecialFunctionsPacketMath.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/AVX/
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/AVX/BesselFunctions.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/AVX/SpecialFunctions.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/AVX512/
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/AVX512/BesselFunctions.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/AVX512/SpecialFunctions.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/GPU/
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/GPU/SpecialFunctions.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/NEON/
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/NEON/BesselFunctions.h
# eigen-3.4.0/unsupported/Eigen/src/SpecialFunctions/arch/NEON/SpecialFunctions.h
# eigen-3.4.0/unsupported/Eigen/src/Splines/
# eigen-3.4.0/unsupported/Eigen/src/Splines/Spline.h
# eigen-3.4.0/unsupported/Eigen/src/Splines/SplineFitting.h
# eigen-3.4.0/unsupported/Eigen/src/Splines/SplineFwd.h
# eigen-3.4.0/unsupported/README.txt
# eigen-3.4.0/unsupported/bench/
# eigen-3.4.0/unsupported/bench/bench_svd.cpp
# eigen-3.4.0/unsupported/doc/
# eigen-3.4.0/unsupported/doc/CMakeLists.txt
# eigen-3.4.0/unsupported/doc/Overview.dox
# eigen-3.4.0/unsupported/doc/SYCL.dox
# eigen-3.4.0/unsupported/doc/eigendoxy_layout.xml.in
# eigen-3.4.0/unsupported/doc/examples/
# eigen-3.4.0/unsupported/doc/examples/BVH_Example.cpp
# eigen-3.4.0/unsupported/doc/examples/CMakeLists.txt
# eigen-3.4.0/unsupported/doc/examples/EulerAngles.cpp
# eigen-3.4.0/unsupported/doc/examples/FFT.cpp
# eigen-3.4.0/unsupported/doc/examples/MatrixExponential.cpp
# eigen-3.4.0/unsupported/doc/examples/MatrixFunction.cpp
# eigen-3.4.0/unsupported/doc/examples/MatrixLogarithm.cpp
# eigen-3.4.0/unsupported/doc/examples/MatrixPower.cpp
# eigen-3.4.0/unsupported/doc/examples/MatrixPower_optimal.cpp
# eigen-3.4.0/unsupported/doc/examples/MatrixSine.cpp
# eigen-3.4.0/unsupported/doc/examples/MatrixSinh.cpp
# eigen-3.4.0/unsupported/doc/examples/MatrixSquareRoot.cpp
# eigen-3.4.0/unsupported/doc/examples/PolynomialSolver1.cpp
# eigen-3.4.0/unsupported/doc/examples/PolynomialUtils1.cpp
# eigen-3.4.0/unsupported/doc/examples/SYCL/
# eigen-3.4.0/unsupported/doc/examples/SYCL/CMakeLists.txt
# eigen-3.4.0/unsupported/doc/examples/SYCL/CwiseMul.cpp
# eigen-3.4.0/unsupported/doc/snippets/
# eigen-3.4.0/unsupported/doc/snippets/CMakeLists.txt
# eigen-3.4.0/unsupported/test/
# eigen-3.4.0/unsupported/test/BVH.cpp
# eigen-3.4.0/unsupported/test/CMakeLists.txt
# eigen-3.4.0/unsupported/test/EulerAngles.cpp
# eigen-3.4.0/unsupported/test/FFT.cpp
# eigen-3.4.0/unsupported/test/FFTW.cpp
# eigen-3.4.0/unsupported/test/NonLinearOptimization.cpp
# eigen-3.4.0/unsupported/test/NumericalDiff.cpp
# eigen-3.4.0/unsupported/test/alignedvector3.cpp
# eigen-3.4.0/unsupported/test/autodiff.cpp
# eigen-3.4.0/unsupported/test/autodiff_scalar.cpp
# eigen-3.4.0/unsupported/test/bessel_functions.cpp
# eigen-3.4.0/unsupported/test/cxx11_eventcount.cpp
# eigen-3.4.0/unsupported/test/cxx11_maxsizevector.cpp
# eigen-3.4.0/unsupported/test/cxx11_meta.cpp
# eigen-3.4.0/unsupported/test/cxx11_non_blocking_thread_pool.cpp
# eigen-3.4.0/unsupported/test/cxx11_runqueue.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_argmax.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_argmax_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_argmax_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_assign.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_block_access.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_block_eval.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_block_io.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_broadcast_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_broadcasting.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_builtins_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_cast_float16_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_casts.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_chipping.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_chipping_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_comparisons.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_complex_cwise_ops_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_complex_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_concatenation.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_concatenation_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_const.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_contract_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_contract_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_contraction.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_convolution.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_convolution_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_custom_index.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_custom_op.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_custom_op_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_device.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_device_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_dimension.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_empty.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_executor.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_expr.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_fft.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_fixed_size.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_forced_eval.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_forced_eval_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_generator.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_generator_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_ifft.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_image_op_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_image_patch.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_image_patch_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_index_list.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_inflation.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_inflation_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_intdiv.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_io.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_layout_swap.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_layout_swap_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_lvalue.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_map.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_math.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_math_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_mixed_indices.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_morphing.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_morphing_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_move.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_notification.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_of_complex.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_of_const_values.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_of_float16_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_of_strings.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_padding.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_padding_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_patch.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_patch_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_random.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_random_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_random_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_reduction.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_reduction_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_reduction_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_ref.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_reverse.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_reverse_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_roundings.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_scan.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_scan_gpu.cu
# eigen-3.4.0/unsupported/test/cxx11_tensor_scan_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_shuffling.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_shuffling_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_simple.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_striding.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_striding_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_sugar.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_sycl.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_symmetry.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_thread_local.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_thread_pool.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_trace.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_uint128.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_volume_patch.cpp
# eigen-3.4.0/unsupported/test/cxx11_tensor_volume_patch_sycl.cpp
# eigen-3.4.0/unsupported/test/dgmres.cpp
# eigen-3.4.0/unsupported/test/forward_adolc.cpp
# eigen-3.4.0/unsupported/test/gmres.cpp
# eigen-3.4.0/unsupported/test/idrs.cpp
# eigen-3.4.0/unsupported/test/kronecker_product.cpp
# eigen-3.4.0/unsupported/test/levenberg_marquardt.cpp
# eigen-3.4.0/unsupported/test/matrix_exponential.cpp
# eigen-3.4.0/unsupported/test/matrix_function.cpp
# eigen-3.4.0/unsupported/test/matrix_functions.h
# eigen-3.4.0/unsupported/test/matrix_power.cpp
# eigen-3.4.0/unsupported/test/matrix_square_root.cpp
# eigen-3.4.0/unsupported/test/minres.cpp
# eigen-3.4.0/unsupported/test/mpreal_support.cpp
# eigen-3.4.0/unsupported/test/openglsupport.cpp
# eigen-3.4.0/unsupported/test/polynomialsolver.cpp
# eigen-3.4.0/unsupported/test/polynomialutils.cpp
# eigen-3.4.0/unsupported/test/sparse_extra.cpp
# eigen-3.4.0/unsupported/test/special_functions.cpp
# eigen-3.4.0/unsupported/test/special_packetmath.cpp
# eigen-3.4.0/unsupported/test/splines.cpp

# %% [markdown]
# Compile and Run - CPU

# %%
# !g++ fashion_mnist_host.cpp -I eigen-3.4.0 -o fashion_mnist_host

# %%
# !./fashion_mnist_host
# Out:
# Loaded 60000 training samples.
# Epoch 1, Average Loss: 1.12491, Accuracy: 0.564833, Epoch Time: 512709 ms
# Epoch 2, Average Loss: 0.448881, Accuracy: 0.836367, Epoch Time: 509094 ms
# Epoch 3, Average Loss: 0.392269, Accuracy: 0.8567, Epoch Time: 509171 ms
# Epoch 4, Average Loss: 0.361197, Accuracy: 0.8676, Epoch Time: 510404 ms
# Epoch 5, Average Loss: 0.340561, Accuracy: 0.87405, Epoch Time: 512290 ms
# Epoch 6, Average Loss: 0.321715, Accuracy: 0.88015, Epoch Time: 510359 ms
# Epoch 7, Average Loss: 0.310083, Accuracy: 0.884433, Epoch Time: 511706 ms
# Epoch 8, Average Loss: 0.301402, Accuracy: 0.8872, Epoch Time: 508566 ms
# Epoch 9, Average Loss: 0.290712, Accuracy: 0.890967, Epoch Time: 512030 ms
# Epoch 10, Average Loss: 0.283167, Accuracy: 0.89435, Epoch Time: 514994 ms

# %% [markdown]
# Basic Kernel

# %%
# !nvcc -o basic_kernel BasicKernel.cu

# %%
# !./basic_kernel
# Out:
# Loaded 60000 training samples.
# Epoch 1, Average Loss: 1.12702, Accuracy: 0.561633, Epoch Time: 16458 ms
# Epoch 2, Average Loss: 0.449983, Accuracy: 0.8366, Epoch Time: 16339 ms
# Epoch 3, Average Loss: 0.391583, Accuracy: 0.856583, Epoch Time: 16473 ms
# Epoch 4, Average Loss: 0.360872, Accuracy: 0.86775, Epoch Time: 16296 ms
# Epoch 5, Average Loss: 0.338907, Accuracy: 0.875167, Epoch Time: 16040 ms
# Epoch 6, Average Loss: 0.322671, Accuracy: 0.880433, Epoch Time: 16191 ms
# Epoch 7, Average Loss: 0.309904, Accuracy: 0.884417, Epoch Time: 16073 ms
# Epoch 8, Average Loss: 0.294593, Accuracy: 0.8887, Epoch Time: 16276 ms
# Epoch 9, Average Loss: 0.287604, Accuracy: 0.891883, Epoch Time: 16490 ms
# Epoch 10, Average Loss: 0.27525, Accuracy: 0.897617, Epoch Time: 16221 ms

# %% [markdown]
# Optimized Kernel 1

# %%
# !nvcc -o optimized_kernel OptimizedKernel1.cu

# %%
# !./optimized_kernel
# Out:
# Loaded 60000 training samples.
# Epoch 1, Average Loss: 1.14724, Accuracy: 0.558883, Epoch Time: 13680 ms
# Epoch 2, Average Loss: 0.452151, Accuracy: 0.833683, Epoch Time: 13449 ms
# Epoch 3, Average Loss: 0.395224, Accuracy: 0.85385, Epoch Time: 13340 ms
# Epoch 4, Average Loss: 0.363905, Accuracy: 0.864767, Epoch Time: 13329 ms
# Epoch 5, Average Loss: 0.343728, Accuracy: 0.87155, Epoch Time: 13288 ms
# Epoch 6, Average Loss: 0.327634, Accuracy: 0.877017, Epoch Time: 13278 ms
# Epoch 7, Average Loss: 0.315788, Accuracy: 0.8817, Epoch Time: 13283 ms
# Epoch 8, Average Loss: 0.303139, Accuracy: 0.88655, Epoch Time: 13315 ms
# Epoch 9, Average Loss: 0.294405, Accuracy: 0.889617, Epoch Time: 13323 ms
# Epoch 10, Average Loss: 0.285016, Accuracy: 0.8929, Epoch Time: 13303 ms

# %% [markdown]
# Optimized Kernel 2

# %%
# !nvcc -o stream_optimized StreamOptimized.cu
# !./stream_optimized
# Out:
# Loaded 60000 training samples.
# Epoch 1, Average Loss: 1.1485, Accuracy: 0.555783, Epoch Time: 16064 ms
# Epoch 2, Average Loss: 0.453167, Accuracy: 0.833933, Epoch Time: 15852 ms
# Epoch 3, Average Loss: 0.396645, Accuracy: 0.854833, Epoch Time: 16089 ms
# Epoch 4, Average Loss: 0.365575, Accuracy: 0.865783, Epoch Time: 15911 ms
# Epoch 5, Average Loss: 0.343712, Accuracy: 0.873267, Epoch Time: 15931 ms
# Epoch 6, Average Loss: 0.326801, Accuracy: 0.8783, Epoch Time: 16003 ms
# Epoch 7, Average Loss: 0.312534, Accuracy: 0.883133, Epoch Time: 16010 ms
# Epoch 8, Average Loss: 0.300962, Accuracy: 0.887083, Epoch Time: 15894 ms
# Epoch 9, Average Loss: 0.291087, Accuracy: 0.89075, Epoch Time: 15967 ms
# Epoch 10, Average Loss: 0.28473, Accuracy: 0.892517, Epoch Time: 16121 ms
